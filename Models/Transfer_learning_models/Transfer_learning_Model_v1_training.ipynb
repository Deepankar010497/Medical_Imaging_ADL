# %% [markdown]
# # InceptionV3 Model Building and Training Notebook
#
# ### This code is in developmental stage. Later will be translated for Azure Cloud implementation.
#
# ### To use this code, dataset has been stored in google drive and gdrive path is mounted for use in notebook.

# %%
try:
  import os, sys 
  #to be able to interact with Google Drive's operating system
  from google.colab import drive 
  #drive is a module that allows us use Python to interact with google drive
  drive.mount('/content/gdrive') 
  #mounting google drive allows us to work with its contents
  nb_path = '/content/notebooks'
  os.symlink('/content/gdrive/My Drive/Colab Notebooks', nb_path)
  sys.path.insert(0, nb_path)  # or append(nb_path)
  #The last three lines are what changes the path of the file.
except:
  print("Drive already mounted and ready to use!")
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %%
# Storing all required paths for later use

main_cwd = r'/content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging'
model_cwd = os.path.join(main_cwd, "Models")
dataset_cwd = os.path.join(main_cwd, "Datasets")
image_data_cwd = os.path.join(main_cwd, "Saved Image Data Arrays")
saved_models_cwd = os.path.join(main_cwd, "Saved_models")
model_checkpoints_cwd = os.path.join(main_cwd, "Model_check_points")
healthy_bones_dataset_cwd = os.path.join(dataset_cwd, "Healthy_bones")
fractured_bones_dataset_cwd = os.path.join(dataset_cwd, "Fractured_bones")
beyond_repair_bones_dataset_cwd = os.path.join(dataset_cwd, "Bones_beyond_repair")
train_test_valid_x_image_data = os.path.join(image_data_cwd, "three_classes", "train_test_valid_x_images_compressed_data_array_224.npz")
train_test_valid_y_labels_data = os.path.join(image_data_cwd, "three_classes", "train_test_valid_y_labels_compressed_array_224.npy")

# %%
# Importing required libraries

from tensorflow import keras
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import BatchNormalization, Activation
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import tensorflow as tf
import numpy as np
import warnings
import cv2
import re
import os

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Helper functions

# %%
def get_cwd_files(path):

  ignore_files = [".gitkeep", ".gitignore"]
  path_files = os.listdir(path)
  path_files = [file for file in path_files if file not in ignore_files]

  return path_files

# %%
def get_image_data(image_data_process_directory, image_resize_value):

  # Classes for our prediction
  classification_classes = ["Healthy_bones", "Fractured_bones", "Bones_beyond_repair"]
  classification_classes_dict = {1:"Healthy_bones", 2:"Fractured_bones", 3:"Bones_beyond_repair"}
  # Set Image size
  img_size = image_resize_value

  #flag_counter = 0
  # Processing image to array
  #data = []
  image_data = []
  label_data = []
  for each_class in classification_classes:
    #flag_counter = 0
    class_category_number = classification_classes.index(each_class)
    bone_class_img_path = os.path.join(image_data_process_directory, each_class)
    #print(bone_class_img_path)
    bone_images = get_cwd_files(bone_class_img_path)
    for bone_image in bone_images:
      
      '''
      if flag_counter == 50:
        break
      flag_counter += 1'''

      bone_image_path = os.path.join(bone_class_img_path, bone_image)
      #print(bone_image_path)
      try:
        x_ray_image = load_img(bone_image_path, target_size=(img_size, img_size))
        x_ray_image = img_to_array(x_ray_image)
        image_data.append(x_ray_image)
        label_data.append(class_category_number)
        #print(x_ray_image.shape)
        #data.append([x_ray_image, class_category_number])
      except:
        print("Some error occured in fetching data!")

  
  #data = np.array(data)
  image_data = np.array(image_data)
  label_data = np.array(label_data) 
  
  return image_data, label_data

# %% [markdown]
# ## Main Program

# %% [markdown]
# Pre processing images to arrays and storing them is done only for the first run and for subsequent runs load the saved array images files for further work to reduce time.

# %%
# Processing train data images
#train_test_valid_x, train_test_valid_y = get_image_data(dataset_cwd, image_resize_value = 224)

# %% [markdown]
# ## Storing values of the image processed array data in csv files

# %%
# Storing Train_test_valid image array values

# For train_test_valid_x compressed values
#np.savez_compressed("train_test_valid_x_images_compressed_data_array_224", train_test_valid_array = train_test_valid_x)

# For train_test_valid_y compressed values
#np.save("train_test_valid_y_labels_compressed_array_224", train_test_valid_y)

# %% [markdown]
# ## Loading Image arrays from the saved files

# %%
# Loading Train image compressed array values

# For train_x values
model_train_test_valid_x = np.load(train_test_valid_x_image_data)["train_test_valid_array"]

# For train_y values
model_train_test_valid_y = np.load(train_test_valid_y_labels_data)

# %%
# Creating train and test dataset
train_valid_x, model_test_x, train_valid_y, model_test_y = train_test_split(model_train_test_valid_x, model_train_test_valid_y, random_state = 42, stratify = model_train_test_valid_y, test_size = 0.10)

# %%
# Creating train and test dataset
model_train_x, model_valid_x, model_train_y, model_valid_y = train_test_split(train_valid_x, train_valid_y, random_state = 42, stratify = train_valid_y, test_size = 0.15)

# %%
# Removing specific variables from runtime to save RAM
del model_train_test_valid_x, model_train_test_valid_y, train_valid_x, train_valid_y

# %%
# Normalizing values
model_train_x, model_train_y = model_train_x/255, model_train_y
model_test_x, model_test_y = model_test_x/255, model_test_y
model_valid_x, model_valid_y = model_valid_x/255, model_valid_y

# %% [markdown]
# ### Data Visualization

# %%
## visualizing some training data
sample_training_data = list(model_train_x[0:50])
sample_training_label = list(model_train_y[0:50])
label_mapping = {0:"Healthy_bones", 1:"Fractured_bones", 2:"Bones_beyond_repair"}

plt.figure(figsize=(15,30))
for i in range(50):
  plt.subplot(10, 5, i + 1)
  img_pil = array_to_img(sample_training_data[i])
  plt.imshow(img_pil, interpolation='nearest')
  plt.title(label_mapping[sample_training_label[i]])
  plt.axis("off")

# %% [markdown]
# ## Hyperparameters for Data Augmentation

# %%
# Hyperparameters for Imagedatagenerator
model_shear_range = 0.2           # Image angular deformation range
model_zoom_range = 0.2            # Image zoom in/out range
model_brightness_range = [0.9,1.2]    # Brightness change range (0.9 to 1.2)
model_rotation_range = 30         # Angular change range
model_width_shift_range = 0.2     # Horizontal shift range
model_height_shift_range = 0.2    # Vertical shift range

# %% [markdown]
# ### Data Augmentation Initilization

# %%
# Image generator for training images
train_gen = ImageDataGenerator(
    rotation_range = model_rotation_range,
    #brightness_range = model_brightness_range,
    #width_shift_range = model_width_shift_range,
    #height_shift_range = model_height_shift_range,
    #zoom_range = model_zoom_range,
    #shear_range = model_shear_range,
    horizontal_flip = True,
    vertical_flip=True,
    #fill_mode = "constant",
    #cval = 0.0  # fill with black color for any blank spaces present after image shift
)

# Image generator fo validation images
valid_gen = ImageDataGenerator()  # No parameters

# %% [markdown]
# ### Data Augmentation

# %%
# Fitting image generator models to datasets 
train_gen.fit(model_train_x)
valid_gen.fit(model_valid_x)

# Creating iter variables for model compile flow
train_iter = train_gen.flow(model_train_x, model_train_y, batch_size = 32)
valid_iter = valid_gen.flow(model_valid_x, model_valid_y, batch_size = 8, shuffle = False)

# %% [markdown]
# ## Hyperparameters for model building

# %%
# Model hyperparameters
model_accuracy = ["acc", "mse"]

# When using all 3 classes (healthy bones, fractured bones and bones beyond repair), then this categorical cross entropy loss
# Using Sparse categorical instead of just categorical as the classes here are considered to be mutually exclusive and hence sparse categorical
# If the sample could have multiple classes or labels (not completely mutually exclusive), then use categorical.
model_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Now as we are working with 2 class currently (healthy bones and fractured bones) we will use binary crossentrophy loss
#model_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Model checkpoints directory as per version of models created (This is version 1)
model_checkpoints_dir = os.path.join(model_checkpoints_cwd, "v1")

model_lr = 0.000001  # 0.000001
model_l2_regularizer_lambda = 0.000001
model_optimizer = Adam(learning_rate = model_lr)
#model_optimizer = RMSprop(learning_rate = model_lr)
model_epochs = 100
model_callbacks = [
                ModelCheckpoint(model_checkpoints_dir, monitor = "val_loss", save_best_only=True, mode="min",options=None),
                EarlyStopping(monitor="val_loss",min_delta=1e-4,patience=8,verbose=1, mode="min",restore_best_weights=True),
                ReduceLROnPlateau(monitor="val_loss",min_delta=1e-4, factor=0.1, patience=3, verbose=1, min_lr=0.0001,mode="min")                
                ]

# After an intial run, we understood as the classes are heavily imbalanced (maybe due to imbalanced dataset or lack of features from the other unpredicted class),
# We use assigning class weights option to let our model train from all classes uniquely, later we will also try to increase our dataset for the better classification
weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(model_train_y), y = model_train_y)
model_class_weights = dict(zip(np.unique(model_train_y), weights))

# %% [markdown]
# ### Model Building

# %%
# Function for getting pre trained model
def get_pre_trained_model_inception():

  try:
    # Importing model excluding the fully connected layer at the top
    model = InceptionV3(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
  
  except:
    print("Pre-trained model Initialization failed !!")

  # Freezing the pretrained model weights so that they wont be updated during back propagation
  for layer in model.layers:
    layer.trainable = False

  last_layer = model.get_layer("mixed7")
  last_output = last_layer.output

  return model, last_output

# %%
# Model Architecture

cnn_model, last_output = get_pre_trained_model_inception()

flattened_last_layer_output = Flatten()(last_output)
dense_layer_1 = Dense(512, kernel_initializer = 'he_uniform', activation='relu')(flattened_last_layer_output)
dense_layer_2 = Dense(128, kernel_initializer = 'he_uniform', activation='relu')(dense_layer_1)
dropout_output = Dropout(0.2)(dense_layer_2)

final_layer = Dense(3, activation="softmax")(dropout_output)
cnn_model = Model(cnn_model.input, final_layer)

cnn_model.compile(optimizer = model_optimizer, loss = model_loss, metrics = model_accuracy)
cnn_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_188 (Conv2D)            (None, 111, 111, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 111, 111, 32  96         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  activation_188 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 109, 109, 32  9216        ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 109, 109, 32  96         ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  activation_189 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_189[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 109, 109, 64  18432       ['activation_189[0][0]']
#                                 )
#
#  batch_normalization_190 (Batch  (None, 109, 109, 64  192        ['conv2d_190[0][0]']
#  Normalization)                 )
#
#  activation_190 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 54, 54, 64)  0           ['activation_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (Batch  (None, 54, 54, 80)  240         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 52, 52, 192)  576        ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_192[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_192[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (Batch  (None, 25, 25, 64)  192         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_196[0][0]']
#
#  batch_normalization_194 (Batch  (None, 25, 25, 48)  144         ['conv2d_194[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 25, 25, 96)  288         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_194[0][0]']
#
#  activation_197 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_197[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_9[0][0]']
#  ooling2D)
#
#  conv2d_193 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_197[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (Batch  (None, 25, 25, 64)  192         ['conv2d_193[0][0]']
#  Normalization)
#
#  batch_normalization_195 (Batch  (None, 25, 25, 64)  192         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 25, 25, 96)  288         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_199 (Batch  (None, 25, 25, 32)  96          ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_193[0][0]']
#
#  activation_195 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_198[0][0]']
#
#  activation_199 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_199[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_193[0][0]',
#                                                                   'activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_203 (Batch  (None, 25, 25, 64)  192         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_203[0][0]']
#
#  batch_normalization_201 (Batch  (None, 25, 25, 48)  144         ['conv2d_201[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 25, 25, 96)  288         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_201[0][0]']
#
#  activation_204 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_204[0][0]']
#
#  average_pooling2d_19 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_200 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (Batch  (None, 25, 25, 64)  192         ['conv2d_200[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 25, 25, 64)  192         ['conv2d_202[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 25, 25, 96)  288         ['conv2d_205[0][0]']
#  Normalization)
#
#  batch_normalization_206 (Batch  (None, 25, 25, 64)  192         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_200[0][0]']
#
#  activation_202 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_202[0][0]']
#
#  activation_205 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_205[0][0]']
#
#  activation_206 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_206[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_200[0][0]',
#                                                                   'activation_202[0][0]',
#                                                                   'activation_205[0][0]',
#                                                                   'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_210 (Batch  (None, 25, 25, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_210[0][0]']
#
#  batch_normalization_208 (Batch  (None, 25, 25, 48)  144         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 25, 25, 96)  288         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_208[0][0]']
#
#  activation_211 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_211[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_207 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (Batch  (None, 25, 25, 64)  192         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_209 (Batch  (None, 25, 25, 64)  192         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 25, 25, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 25, 25, 64)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_207[0][0]']
#
#  activation_209 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_212[0][0]']
#
#  activation_213 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_213[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_207[0][0]',
#                                                                   'activation_209[0][0]',
#                                                                   'activation_212[0][0]',
#                                                                   'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_215 (Batch  (None, 25, 25, 64)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_215[0][0]']
#
#  batch_normalization_216 (Batch  (None, 25, 25, 96)  288         ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_216[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_216[0][0]']
#
#  batch_normalization_214 (Batch  (None, 12, 12, 384)  1152       ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 12, 12, 96)  288         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_214[0][0]']
#
#  activation_217 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_217[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_214[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_222 (Batch  (None, 12, 12, 128)  384        ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 12, 12, 128)  384        ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_223[0][0]']
#
#  batch_normalization_219 (Batch  (None, 12, 12, 128)  384        ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 12, 12, 128)  384        ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_219[0][0]']
#
#  activation_224 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_224[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_224[0][0]']
#
#  batch_normalization_220 (Batch  (None, 12, 12, 128)  384        ['conv2d_220[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 12, 12, 128)  384        ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_220[0][0]']
#
#  activation_225 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_225[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_218 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (Batch  (None, 12, 12, 192)  576        ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 12, 12, 192)  576        ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 12, 12, 192)  576        ['conv2d_226[0][0]']
#  Normalization)
#
#  batch_normalization_227 (Batch  (None, 12, 12, 192)  576        ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_218[0][0]']
#
#  activation_221 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_221[0][0]']
#
#  activation_226 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_226[0][0]']
#
#  activation_227 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_227[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_218[0][0]',
#                                                                   'activation_221[0][0]',
#                                                                   'activation_226[0][0]',
#                                                                   'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_232 (Batch  (None, 12, 12, 160)  480        ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_232[0][0]']
#
#  batch_normalization_233 (Batch  (None, 12, 12, 160)  480        ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_233[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_233[0][0]']
#
#  batch_normalization_229 (Batch  (None, 12, 12, 160)  480        ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 12, 12, 160)  480        ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_229[0][0]']
#
#  activation_234 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_234[0][0]']
#
#  batch_normalization_230 (Batch  (None, 12, 12, 160)  480        ['conv2d_230[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 12, 12, 160)  480        ['conv2d_235[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_230[0][0]']
#
#  activation_235 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_235[0][0]']
#
#  average_pooling2d_22 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_228 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (Batch  (None, 12, 12, 192)  576        ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 12, 12, 192)  576        ['conv2d_231[0][0]']
#  Normalization)
#
#  batch_normalization_236 (Batch  (None, 12, 12, 192)  576        ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 12, 12, 192)  576        ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_231[0][0]']
#
#  activation_236 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_236[0][0]']
#
#  activation_237 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_237[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_228[0][0]',
#                                                                   'activation_231[0][0]',
#                                                                   'activation_236[0][0]',
#                                                                   'activation_237[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_242 (Batch  (None, 12, 12, 160)  480        ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_242[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_242[0][0]']
#
#  batch_normalization_243 (Batch  (None, 12, 12, 160)  480        ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 12, 12, 160)  480        ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 12, 12, 160)  480        ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_239[0][0]']
#
#  activation_244 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_244[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_239[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_244[0][0]']
#
#  batch_normalization_240 (Batch  (None, 12, 12, 160)  480        ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_245 (Batch  (None, 12, 12, 160)  480        ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_240[0][0]']
#
#  activation_245 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_245[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_238 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_240[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_245[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_238 (Batch  (None, 12, 12, 192)  576        ['conv2d_238[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 12, 12, 192)  576        ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 12, 12, 192)  576        ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 12, 12, 192)  576        ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_238[0][0]']
#
#  activation_241 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_241[0][0]']
#
#  activation_246 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_246[0][0]']
#
#  activation_247 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_247[0][0]']
#
#  mixed6 (Concatenate)           (None, 12, 12, 768)  0           ['activation_238[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_246[0][0]',
#                                                                   'activation_247[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed6[0][0]']
#
#  batch_normalization_252 (Batch  (None, 12, 12, 192)  576        ['conv2d_252[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_252[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 12, 12, 192)  258048      ['activation_252[0][0]']
#
#  batch_normalization_253 (Batch  (None, 12, 12, 192)  576        ['conv2d_253[0][0]']
#  Normalization)
#
#  activation_253 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_253[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed6[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 12, 12, 192)  258048      ['activation_253[0][0]']
#
#  batch_normalization_249 (Batch  (None, 12, 12, 192)  576        ['conv2d_249[0][0]']
#  Normalization)
#
#  batch_normalization_254 (Batch  (None, 12, 12, 192)  576        ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_249 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_249[0][0]']
#
#  activation_254 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_254[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 12, 12, 192)  258048      ['activation_249[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 12, 12, 192)  258048      ['activation_254[0][0]']
#
#  batch_normalization_250 (Batch  (None, 12, 12, 192)  576        ['conv2d_250[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 12, 12, 192)  576        ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_250 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_250[0][0]']
#
#  activation_255 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_255[0][0]']
#
#  average_pooling2d_24 (AverageP  (None, 12, 12, 768)  0          ['mixed6[0][0]']
#  ooling2D)
#
#  conv2d_248 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed6[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 12, 12, 192)  258048      ['activation_250[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 12, 12, 192)  258048      ['activation_255[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_24[0][0]']
#
#  batch_normalization_248 (Batch  (None, 12, 12, 192)  576        ['conv2d_248[0][0]']
#  Normalization)
#
#  batch_normalization_251 (Batch  (None, 12, 12, 192)  576        ['conv2d_251[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 12, 12, 192)  576        ['conv2d_256[0][0]']
#  Normalization)
#
#  batch_normalization_257 (Batch  (None, 12, 12, 192)  576        ['conv2d_257[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_248[0][0]']
#
#  activation_251 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_251[0][0]']
#
#  activation_256 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_256[0][0]']
#
#  activation_257 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_257[0][0]']
#
#  mixed7 (Concatenate)           (None, 12, 12, 768)  0           ['activation_248[0][0]',
#                                                                   'activation_251[0][0]',
#                                                                   'activation_256[0][0]',
#                                                                   'activation_257[0][0]']
#
#  flatten_2 (Flatten)            (None, 110592)       0           ['mixed7[0][0]']
#
#  dense_6 (Dense)                (None, 512)          56623616    ['flatten_2[0][0]']
#
#  dense_7 (Dense)                (None, 128)          65664       ['dense_6[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 3)            387         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 65,664,931
# Trainable params: 56,689,667
# Non-trainable params: 8,975,264
# __________________________________________________________________________________________________

# %%
# Model Plot
plot_model(cnn_model,show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

# %%
# Model fit
history = cnn_model.fit(train_iter, validation_data=valid_iter, steps_per_epoch=len(model_train_x)/32, epochs=model_epochs, callbacks=model_callbacks)
# Out:
# Epoch 1/100
# 89/88 [==============================] - ETA: 0s - loss: 1.0402 - acc: 0.4238 - mse: 0.8246INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 83s 887ms/step - loss: 1.0402 - acc: 0.4238 - mse: 0.8246 - val_loss: 0.9612 - val_acc: 0.5180 - val_mse: 0.8251 - lr: 1.0000e-06
# Epoch 2/100
# 89/88 [==============================] - ETA: 0s - loss: 0.9745 - acc: 0.4981 - mse: 0.8288INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 72s 818ms/step - loss: 0.9745 - acc: 0.4981 - mse: 0.8288 - val_loss: 0.8984 - val_acc: 0.6100 - val_mse: 0.8294 - lr: 1.0000e-06
# Epoch 3/100
# 89/88 [==============================] - ETA: 0s - loss: 0.9193 - acc: 0.5394 - mse: 0.8335INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 72s 822ms/step - loss: 0.9193 - acc: 0.5394 - mse: 0.8335 - val_loss: 0.8537 - val_acc: 0.6440 - val_mse: 0.8349 - lr: 1.0000e-06
# Epoch 4/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8726 - acc: 0.5720 - mse: 0.8387INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 72s 817ms/step - loss: 0.8726 - acc: 0.5720 - mse: 0.8387 - val_loss: 0.8156 - val_acc: 0.6400 - val_mse: 0.8403 - lr: 1.0000e-06
# Epoch 5/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8352 - acc: 0.5982 - mse: 0.8450INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 72s 821ms/step - loss: 0.8352 - acc: 0.5982 - mse: 0.8450 - val_loss: 0.7803 - val_acc: 0.6560 - val_mse: 0.8439 - lr: 1.0000e-06
# Epoch 6/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8087 - acc: 0.6031 - mse: 0.8492INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 69s 778ms/step - loss: 0.8087 - acc: 0.6031 - mse: 0.8492 - val_loss: 0.7563 - val_acc: 0.6700 - val_mse: 0.8508 - lr: 1.0000e-06
# Epoch 7/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7630 - acc: 0.6512 - mse: 0.8559INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 771ms/step - loss: 0.7630 - acc: 0.6512 - mse: 0.8559 - val_loss: 0.7423 - val_acc: 0.6740 - val_mse: 0.8540 - lr: 1.0000e-06
# Epoch 8/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7478 - acc: 0.6473 - mse: 0.8580INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 770ms/step - loss: 0.7478 - acc: 0.6473 - mse: 0.8580 - val_loss: 0.7162 - val_acc: 0.6740 - val_mse: 0.8597 - lr: 1.0000e-06
# Epoch 9/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7323 - acc: 0.6678 - mse: 0.8631INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 763ms/step - loss: 0.7323 - acc: 0.6678 - mse: 0.8631 - val_loss: 0.7067 - val_acc: 0.6860 - val_mse: 0.8613 - lr: 1.0000e-06
# Epoch 10/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7045 - acc: 0.6866 - mse: 0.8658INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 777ms/step - loss: 0.7045 - acc: 0.6866 - mse: 0.8658 - val_loss: 0.6849 - val_acc: 0.6900 - val_mse: 0.8660 - lr: 1.0000e-06
# Epoch 11/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6879 - acc: 0.6972 - mse: 0.8689INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 771ms/step - loss: 0.6879 - acc: 0.6972 - mse: 0.8689 - val_loss: 0.6726 - val_acc: 0.7000 - val_mse: 0.8696 - lr: 1.0000e-06
# Epoch 12/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6733 - acc: 0.6990 - mse: 0.8723INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 70s 793ms/step - loss: 0.6733 - acc: 0.6990 - mse: 0.8723 - val_loss: 0.6628 - val_acc: 0.7080 - val_mse: 0.8730 - lr: 1.0000e-06
# Epoch 13/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6613 - acc: 0.7064 - mse: 0.8760INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 763ms/step - loss: 0.6613 - acc: 0.7064 - mse: 0.8760 - val_loss: 0.6433 - val_acc: 0.7060 - val_mse: 0.8765 - lr: 1.0000e-06
# Epoch 14/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6399 - acc: 0.7160 - mse: 0.8798INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 767ms/step - loss: 0.6399 - acc: 0.7160 - mse: 0.8798 - val_loss: 0.6403 - val_acc: 0.7200 - val_mse: 0.8773 - lr: 1.0000e-06
# Epoch 15/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6227 - acc: 0.7287 - mse: 0.8825INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 65s 739ms/step - loss: 0.6227 - acc: 0.7287 - mse: 0.8825 - val_loss: 0.6325 - val_acc: 0.7180 - val_mse: 0.8805 - lr: 1.0000e-06
# Epoch 16/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6275 - acc: 0.7142 - mse: 0.8834INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 772ms/step - loss: 0.6275 - acc: 0.7142 - mse: 0.8834 - val_loss: 0.6214 - val_acc: 0.7200 - val_mse: 0.8827 - lr: 1.0000e-06
# Epoch 17/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6033 - acc: 0.7343 - mse: 0.8867INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 70s 793ms/step - loss: 0.6033 - acc: 0.7343 - mse: 0.8867 - val_loss: 0.6144 - val_acc: 0.7320 - val_mse: 0.8846 - lr: 1.0000e-06
# Epoch 18/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5932 - acc: 0.7400 - mse: 0.8887INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 776ms/step - loss: 0.5932 - acc: 0.7400 - mse: 0.8887 - val_loss: 0.6036 - val_acc: 0.7300 - val_mse: 0.8873 - lr: 1.0000e-06
# Epoch 19/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5888 - acc: 0.7474 - mse: 0.8904INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 764ms/step - loss: 0.5888 - acc: 0.7474 - mse: 0.8904 - val_loss: 0.6029 - val_acc: 0.7400 - val_mse: 0.8873 - lr: 1.0000e-06
# Epoch 20/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5764 - acc: 0.7407 - mse: 0.8918INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 772ms/step - loss: 0.5764 - acc: 0.7407 - mse: 0.8918 - val_loss: 0.5965 - val_acc: 0.7440 - val_mse: 0.8900 - lr: 1.0000e-06
# Epoch 21/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5632 - acc: 0.7595 - mse: 0.8946INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 769ms/step - loss: 0.5632 - acc: 0.7595 - mse: 0.8946 - val_loss: 0.5915 - val_acc: 0.7380 - val_mse: 0.8908 - lr: 1.0000e-06
# Epoch 22/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5597 - acc: 0.7580 - mse: 0.8961INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 769ms/step - loss: 0.5597 - acc: 0.7580 - mse: 0.8961 - val_loss: 0.5906 - val_acc: 0.7280 - val_mse: 0.8904 - lr: 1.0000e-06
# Epoch 23/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5670 - acc: 0.7570 - mse: 0.8966INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 774ms/step - loss: 0.5670 - acc: 0.7570 - mse: 0.8966 - val_loss: 0.5813 - val_acc: 0.7340 - val_mse: 0.8926 - lr: 1.0000e-06
# Epoch 24/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5499 - acc: 0.7672 - mse: 0.8988INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 763ms/step - loss: 0.5499 - acc: 0.7672 - mse: 0.8988 - val_loss: 0.5762 - val_acc: 0.7600 - val_mse: 0.8952 - lr: 1.0000e-06
# Epoch 25/100
# 88/88 [==============================] - 39s 444ms/step - loss: 0.5408 - acc: 0.7683 - mse: 0.9014 - val_loss: 0.5796 - val_acc: 0.7500 - val_mse: 0.8956 - lr: 1.0000e-06
# Epoch 26/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5358 - acc: 0.7641 - mse: 0.9010INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 64s 731ms/step - loss: 0.5358 - acc: 0.7641 - mse: 0.9010 - val_loss: 0.5742 - val_acc: 0.7480 - val_mse: 0.8987 - lr: 1.0000e-06
# Epoch 27/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5190 - acc: 0.7828 - mse: 0.9039INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 758ms/step - loss: 0.5190 - acc: 0.7828 - mse: 0.9039 - val_loss: 0.5736 - val_acc: 0.7560 - val_mse: 0.8985 - lr: 1.0000e-06
# Epoch 28/100
# 89/88 [==============================] - ETA: 0s - loss: 0.5226 - acc: 0.7828 - mse: 0.9048INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 777ms/step - loss: 0.5226 - acc: 0.7828 - mse: 0.9048 - val_loss: 0.5668 - val_acc: 0.7640 - val_mse: 0.8993 - lr: 1.0000e-06
# Epoch 29/100
# 88/88 [==============================] - 40s 449ms/step - loss: 0.5161 - acc: 0.7779 - mse: 0.9060 - val_loss: 0.5679 - val_acc: 0.7520 - val_mse: 0.8993 - lr: 1.0000e-06
# Epoch 30/100
# 88/88 [==============================] - 37s 423ms/step - loss: 0.5059 - acc: 0.7871 - mse: 0.9061 - val_loss: 0.5681 - val_acc: 0.7500 - val_mse: 0.9002 - lr: 1.0000e-06
# Epoch 31/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4929 - acc: 0.7906 - mse: 0.9080INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 65s 739ms/step - loss: 0.4929 - acc: 0.7906 - mse: 0.9080 - val_loss: 0.5603 - val_acc: 0.7600 - val_mse: 0.9022 - lr: 1.0000e-06
# Epoch 32/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4955 - acc: 0.7994 - mse: 0.9093INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 777ms/step - loss: 0.4955 - acc: 0.7994 - mse: 0.9093 - val_loss: 0.5559 - val_acc: 0.7620 - val_mse: 0.9036 - lr: 1.0000e-06
# Epoch 33/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4935 - acc: 0.7963 - mse: 0.9094INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 772ms/step - loss: 0.4935 - acc: 0.7963 - mse: 0.9094 - val_loss: 0.5535 - val_acc: 0.7720 - val_mse: 0.9047 - lr: 1.0000e-06
# Epoch 34/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4943 - acc: 0.7913 - mse: 0.9108INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 764ms/step - loss: 0.4943 - acc: 0.7913 - mse: 0.9108 - val_loss: 0.5491 - val_acc: 0.7680 - val_mse: 0.9052 - lr: 1.0000e-06
# Epoch 35/100
# 88/88 [==============================] - 40s 457ms/step - loss: 0.4910 - acc: 0.8005 - mse: 0.9112 - val_loss: 0.5569 - val_acc: 0.7580 - val_mse: 0.9046 - lr: 1.0000e-06
# Epoch 36/100
# 88/88 [==============================] - 38s 424ms/step - loss: 0.4830 - acc: 0.7927 - mse: 0.9121 - val_loss: 0.5608 - val_acc: 0.7420 - val_mse: 0.9038 - lr: 1.0000e-06
# Epoch 37/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4788 - acc: 0.8118 - mse: 0.9122INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 65s 736ms/step - loss: 0.4788 - acc: 0.8118 - mse: 0.9122 - val_loss: 0.5454 - val_acc: 0.7620 - val_mse: 0.9059 - lr: 1.0000e-06
# Epoch 38/100
# 88/88 [==============================] - 39s 443ms/step - loss: 0.4827 - acc: 0.8005 - mse: 0.9144 - val_loss: 0.5498 - val_acc: 0.7520 - val_mse: 0.9057 - lr: 1.0000e-06
# Epoch 39/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4739 - acc: 0.7980 - mse: 0.9138INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 66s 754ms/step - loss: 0.4739 - acc: 0.7980 - mse: 0.9138 - val_loss: 0.5453 - val_acc: 0.7660 - val_mse: 0.9076 - lr: 1.0000e-06
# Epoch 40/100
# 88/88 [==============================] - 39s 445ms/step - loss: 0.4715 - acc: 0.8001 - mse: 0.9144 - val_loss: 0.5533 - val_acc: 0.7540 - val_mse: 0.9062 - lr: 1.0000e-06
# Epoch 41/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4746 - acc: 0.8058 - mse: 0.9151INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 66s 753ms/step - loss: 0.4746 - acc: 0.8058 - mse: 0.9151 - val_loss: 0.5438 - val_acc: 0.7720 - val_mse: 0.9104 - lr: 1.0000e-06
# Epoch 42/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4572 - acc: 0.8157 - mse: 0.9176INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 69s 780ms/step - loss: 0.4572 - acc: 0.8157 - mse: 0.9176 - val_loss: 0.5430 - val_acc: 0.7620 - val_mse: 0.9107 - lr: 1.0000e-06
# Epoch 43/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4523 - acc: 0.8093 - mse: 0.9183INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 770ms/step - loss: 0.4523 - acc: 0.8093 - mse: 0.9183 - val_loss: 0.5421 - val_acc: 0.7660 - val_mse: 0.9089 - lr: 1.0000e-06
# Epoch 44/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4596 - acc: 0.8072 - mse: 0.9184INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 70s 798ms/step - loss: 0.4596 - acc: 0.8072 - mse: 0.9184 - val_loss: 0.5350 - val_acc: 0.7720 - val_mse: 0.9106 - lr: 1.0000e-06
# Epoch 45/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4351 - acc: 0.8207 - mse: 0.9190INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 69s 780ms/step - loss: 0.4351 - acc: 0.8207 - mse: 0.9190 - val_loss: 0.5281 - val_acc: 0.7820 - val_mse: 0.9132 - lr: 1.0000e-06
# Epoch 46/100
# 88/88 [==============================] - 39s 445ms/step - loss: 0.4474 - acc: 0.8203 - mse: 0.9191 - val_loss: 0.5301 - val_acc: 0.7840 - val_mse: 0.9163 - lr: 1.0000e-06
# Epoch 47/100
# 88/88 [==============================] - 39s 437ms/step - loss: 0.4405 - acc: 0.8189 - mse: 0.9206 - val_loss: 0.5328 - val_acc: 0.7760 - val_mse: 0.9121 - lr: 1.0000e-06
# Epoch 48/100
# 88/88 [==============================] - 38s 429ms/step - loss: 0.4433 - acc: 0.8196 - mse: 0.9198 - val_loss: 0.5298 - val_acc: 0.7740 - val_mse: 0.9134 - lr: 1.0000e-06
# Epoch 49/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4220 - acc: 0.8320 - mse: 0.9218INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 761ms/step - loss: 0.4220 - acc: 0.8320 - mse: 0.9218 - val_loss: 0.5279 - val_acc: 0.7820 - val_mse: 0.9180 - lr: 1.0000e-06
# Epoch 50/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4314 - acc: 0.8115 - mse: 0.9238INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 764ms/step - loss: 0.4314 - acc: 0.8115 - mse: 0.9238 - val_loss: 0.5274 - val_acc: 0.7740 - val_mse: 0.9131 - lr: 1.0000e-06
# Epoch 51/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4283 - acc: 0.8210 - mse: 0.9225INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 767ms/step - loss: 0.4283 - acc: 0.8210 - mse: 0.9225 - val_loss: 0.5213 - val_acc: 0.7960 - val_mse: 0.9163 - lr: 1.0000e-06
# Epoch 52/100
# 88/88 [==============================] - 39s 443ms/step - loss: 0.4123 - acc: 0.8352 - mse: 0.9239 - val_loss: 0.5227 - val_acc: 0.7760 - val_mse: 0.9163 - lr: 1.0000e-06
# Epoch 53/100
# 88/88 [==============================] - 37s 419ms/step - loss: 0.4219 - acc: 0.8348 - mse: 0.9245 - val_loss: 0.5326 - val_acc: 0.7760 - val_mse: 0.9146 - lr: 1.0000e-06
# Epoch 54/100
# 88/88 [==============================] - 37s 421ms/step - loss: 0.4094 - acc: 0.8306 - mse: 0.9256 - val_loss: 0.5237 - val_acc: 0.7800 - val_mse: 0.9163 - lr: 1.0000e-06
# Epoch 55/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4225 - acc: 0.8291 - mse: 0.9243INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 65s 738ms/step - loss: 0.4225 - acc: 0.8291 - mse: 0.9243 - val_loss: 0.5203 - val_acc: 0.7740 - val_mse: 0.9169 - lr: 1.0000e-06
# Epoch 56/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4124 - acc: 0.8376 - mse: 0.9257INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 774ms/step - loss: 0.4124 - acc: 0.8376 - mse: 0.9257 - val_loss: 0.5192 - val_acc: 0.7820 - val_mse: 0.9180 - lr: 1.0000e-06
# Epoch 57/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4019 - acc: 0.8412 - mse: 0.9276INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 760ms/step - loss: 0.4019 - acc: 0.8412 - mse: 0.9276 - val_loss: 0.5151 - val_acc: 0.7960 - val_mse: 0.9189 - lr: 1.0000e-06
# Epoch 58/100
# 88/88 [==============================] - 40s 457ms/step - loss: 0.4085 - acc: 0.8366 - mse: 0.9266 - val_loss: 0.5184 - val_acc: 0.7860 - val_mse: 0.9188 - lr: 1.0000e-06
# Epoch 59/100
# 88/88 [==============================] - 38s 426ms/step - loss: 0.3994 - acc: 0.8419 - mse: 0.9269 - val_loss: 0.5212 - val_acc: 0.7920 - val_mse: 0.9203 - lr: 1.0000e-06
# Epoch 60/100
# 88/88 [==============================] - 39s 438ms/step - loss: 0.3951 - acc: 0.8369 - mse: 0.9275 - val_loss: 0.5201 - val_acc: 0.7800 - val_mse: 0.9205 - lr: 1.0000e-06
# Epoch 61/100
# 88/88 [==============================] - 38s 434ms/step - loss: 0.3976 - acc: 0.8461 - mse: 0.9294 - val_loss: 0.5192 - val_acc: 0.7860 - val_mse: 0.9210 - lr: 1.0000e-06
# Epoch 62/100
# 89/88 [==============================] - ETA: 0s - loss: 0.4026 - acc: 0.8398 - mse: 0.9283INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 766ms/step - loss: 0.4026 - acc: 0.8398 - mse: 0.9283 - val_loss: 0.5133 - val_acc: 0.7880 - val_mse: 0.9207 - lr: 1.0000e-06
# Epoch 63/100
# 88/88 [==============================] - 41s 465ms/step - loss: 0.3952 - acc: 0.8458 - mse: 0.9290 - val_loss: 0.5184 - val_acc: 0.7780 - val_mse: 0.9191 - lr: 1.0000e-06
# Epoch 64/100
# 88/88 [==============================] - 38s 434ms/step - loss: 0.3956 - acc: 0.8419 - mse: 0.9298 - val_loss: 0.5145 - val_acc: 0.7860 - val_mse: 0.9235 - lr: 1.0000e-06
# Epoch 65/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3808 - acc: 0.8465 - mse: 0.9303INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 65s 740ms/step - loss: 0.3808 - acc: 0.8465 - mse: 0.9303 - val_loss: 0.5118 - val_acc: 0.7960 - val_mse: 0.9250 - lr: 1.0000e-06
# Epoch 66/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3789 - acc: 0.8486 - mse: 0.9314INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 771ms/step - loss: 0.3789 - acc: 0.8486 - mse: 0.9314 - val_loss: 0.5114 - val_acc: 0.7880 - val_mse: 0.9227 - lr: 1.0000e-06
# Epoch 67/100
# 88/88 [==============================] - 40s 450ms/step - loss: 0.3798 - acc: 0.8521 - mse: 0.9317 - val_loss: 0.5117 - val_acc: 0.7800 - val_mse: 0.9215 - lr: 1.0000e-06
# Epoch 68/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3724 - acc: 0.8578 - mse: 0.9314INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 65s 743ms/step - loss: 0.3724 - acc: 0.8578 - mse: 0.9314 - val_loss: 0.5099 - val_acc: 0.7940 - val_mse: 0.9249 - lr: 1.0000e-06
# Epoch 69/100
# 88/88 [==============================] - 40s 457ms/step - loss: 0.3769 - acc: 0.8486 - mse: 0.9322 - val_loss: 0.5157 - val_acc: 0.7840 - val_mse: 0.9236 - lr: 1.0000e-06
# Epoch 70/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3739 - acc: 0.8550 - mse: 0.9328INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 66s 745ms/step - loss: 0.3739 - acc: 0.8550 - mse: 0.9328 - val_loss: 0.5082 - val_acc: 0.7960 - val_mse: 0.9251 - lr: 1.0000e-06
# Epoch 71/100
# 88/88 [==============================] - 41s 459ms/step - loss: 0.3742 - acc: 0.8536 - mse: 0.9327 - val_loss: 0.5150 - val_acc: 0.7720 - val_mse: 0.9216 - lr: 1.0000e-06
# Epoch 72/100
# 88/88 [==============================] - 38s 432ms/step - loss: 0.3719 - acc: 0.8546 - mse: 0.9326 - val_loss: 0.5111 - val_acc: 0.7880 - val_mse: 0.9222 - lr: 1.0000e-06
# Epoch 73/100
# 88/88 [==============================] - 38s 432ms/step - loss: 0.3659 - acc: 0.8603 - mse: 0.9346 - val_loss: 0.5109 - val_acc: 0.7800 - val_mse: 0.9233 - lr: 1.0000e-06
# Epoch 74/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3692 - acc: 0.8603 - mse: 0.9346INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 67s 757ms/step - loss: 0.3692 - acc: 0.8603 - mse: 0.9346 - val_loss: 0.5072 - val_acc: 0.7940 - val_mse: 0.9247 - lr: 1.0000e-06
# Epoch 75/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3641 - acc: 0.8606 - mse: 0.9341INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 69s 780ms/step - loss: 0.3641 - acc: 0.8606 - mse: 0.9341 - val_loss: 0.5053 - val_acc: 0.7940 - val_mse: 0.9251 - lr: 1.0000e-06
# Epoch 76/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3596 - acc: 0.8560 - mse: 0.9350INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 68s 773ms/step - loss: 0.3596 - acc: 0.8560 - mse: 0.9350 - val_loss: 0.5026 - val_acc: 0.8040 - val_mse: 0.9270 - lr: 1.0000e-06
# Epoch 77/100
# 88/88 [==============================] - 40s 454ms/step - loss: 0.3542 - acc: 0.8656 - mse: 0.9352 - val_loss: 0.5030 - val_acc: 0.8060 - val_mse: 0.9281 - lr: 1.0000e-06
# Epoch 78/100
# 88/88 [==============================] - 38s 430ms/step - loss: 0.3665 - acc: 0.8486 - mse: 0.9351 - val_loss: 0.5088 - val_acc: 0.7920 - val_mse: 0.9289 - lr: 1.0000e-06
# Epoch 79/100
# 88/88 [==============================] - 38s 425ms/step - loss: 0.3497 - acc: 0.8642 - mse: 0.9379 - val_loss: 0.5114 - val_acc: 0.7840 - val_mse: 0.9284 - lr: 1.0000e-06
# Epoch 80/100
# 88/88 [==============================] - 38s 426ms/step - loss: 0.3516 - acc: 0.8628 - mse: 0.9367 - val_loss: 0.5076 - val_acc: 0.7840 - val_mse: 0.9258 - lr: 1.0000e-06
# Epoch 81/100
# 88/88 [==============================] - 38s 430ms/step - loss: 0.3481 - acc: 0.8578 - mse: 0.9378 - val_loss: 0.5061 - val_acc: 0.7960 - val_mse: 0.9283 - lr: 1.0000e-06
# Epoch 82/100
# 88/88 [==============================] - 38s 426ms/step - loss: 0.3512 - acc: 0.8652 - mse: 0.9363 - val_loss: 0.5119 - val_acc: 0.7920 - val_mse: 0.9312 - lr: 1.0000e-06
# Epoch 83/100
# 88/88 [==============================] - 38s 425ms/step - loss: 0.3498 - acc: 0.8698 - mse: 0.9369 - val_loss: 0.5036 - val_acc: 0.7900 - val_mse: 0.9282 - lr: 1.0000e-06
# Epoch 84/100
# 89/88 [==============================] - ETA: 0s - loss: 0.3524 - acc: 0.8606 - mse: 0.9380Restoring model weights from the end of the best epoch: 76.
# 88/88 [==============================] - 38s 426ms/step - loss: 0.3524 - acc: 0.8606 - mse: 0.9380 - val_loss: 0.5036 - val_acc: 0.7920 - val_mse: 0.9298 - lr: 1.0000e-06
# Epoch 84: early stopping

# %%
# Save model
keras.models.save_model(cnn_model, "Transfer_learning_model_v1.h5", save_format="h5")

# %%
# Model History Plot
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
mse = history.history['mse']
val_mse = history.history['val_mse']
epochs_range = range(len(history.history['loss']))

plt.figure(0)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, acc, 'r', label='Training Accuracy')
plt.plot(epochs_range, val_acc, 'g', label='Validation Accuracy')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.title('Training vs Validation Accuracy')

plt.figure(1)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.title('Training vs Validation Loss')

plt.figure(2)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, mse, label='Training mse')
plt.plot(epochs_range, val_mse, label='Validation mse')
plt.xlabel("Num of Epochs")
plt.ylabel("MSE")
plt.legend(loc='upper right')
plt.title('Training vs Validation MSE')

plt.show()

# %% [markdown]
# ## Prediction Stats

# %%
# Finding Prediction Error

# Since for now we are dealing with a binary classifciation problem (healthy bones and fractured bones), we use the following method
# Later when we continue working with all 3 classes (healthy bones, fractured bones and bones beyond repair), we will change the below maths accordingly
model_test_prediction_labels = cnn_model.predict(model_test_x)
model_test_prediction_list = []

for label_prediction in model_test_prediction_labels:
    model_test_prediction_list.append(np.argmax(label_prediction))


prediction_error = np.sum(np.not_equal(model_test_prediction_list, list(model_test_y))) / model_test_y.shape[0]
print(f"The prediction error for the model is {prediction_error}")
# Out:
# The prediction error for the model is 0.23783783783783785

# %% [markdown]
# #### The model prediction error should be close to zero. The above value will show how much the model needs more tuning and optimization in order to have prediction error closer to zero.

# %%
# Model testing stats
model_evaluation = cnn_model.evaluate(model_test_x, model_test_y, batch_size=8)
print(dict(zip(cnn_model.metrics_names, model_evaluation)))
# Out:
# 47/47 [==============================] - 5s 71ms/step - loss: 0.5154 - acc: 0.7622 - mse: 0.9295
# {'loss': 0.5154107809066772, 'acc': 0.7621621489524841, 'mse': 0.9295064806938171}

# %% [markdown]
# ## Metric Stats

# %%
# Classification Report:
print('Classification Report: ')
print(classification_report(list(model_test_y), model_test_prediction_list, target_names=["0","1", "2"]))

# Confusion Matrix
print('Confusion Matrix: ')
cm = confusion_matrix(model_test_prediction_list, list(model_test_y))
plt.figure(figsize = (7.5,5))
sns.set(font_scale=1.4) # for label size
sns.heatmap(cm, annot=True, annot_kws={"size": 20},cmap="YlGnBu") # font size
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.89      0.80       150
#            1       0.75      0.57      0.65       141
#            2       0.87      0.85      0.86        79
#
#     accuracy                           0.76       370
#    macro avg       0.78      0.77      0.77       370
# weighted avg       0.77      0.76      0.76       370
#
# Confusion Matrix:
