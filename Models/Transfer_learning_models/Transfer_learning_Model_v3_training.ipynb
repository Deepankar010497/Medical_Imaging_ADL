# %% [markdown]
# # VGG19 Model Building and Training Notebook
#
# ### This code is in developmental stage. Later will be translated for Azure Cloud implementation.
#
# ### To use this code, dataset has been stored in google drive and gdrive path is mounted for use in notebook.

# %%
try:
  import os, sys 
  #to be able to interact with Google Drive's operating system
  from google.colab import drive 
  #drive is a module that allows us use Python to interact with google drive
  drive.mount('/content/gdrive') 
  #mounting google drive allows us to work with its contents
  nb_path = '/content/notebooks'
  os.symlink('/content/gdrive/My Drive/Colab Notebooks', nb_path)
  sys.path.insert(0, nb_path)  # or append(nb_path)
  #The last three lines are what changes the path of the file.
except:
  print("Drive already mounted and ready to use!")
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %%
# Storing all required paths for later use

main_cwd = r'/content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging'
model_cwd = os.path.join(main_cwd, "Models")
dataset_cwd = os.path.join(main_cwd, "Datasets")
image_data_cwd = os.path.join(main_cwd, "Saved Image Data Arrays")
saved_models_cwd = os.path.join(main_cwd, "Saved_models")
model_checkpoints_cwd = os.path.join(main_cwd, "Model_check_points")
healthy_bones_dataset_cwd = os.path.join(dataset_cwd, "Healthy_bones")
fractured_bones_dataset_cwd = os.path.join(dataset_cwd, "Fractured_bones")
beyond_repair_bones_dataset_cwd = os.path.join(dataset_cwd, "Bones_beyond_repair")
train_test_valid_x_image_data = os.path.join(image_data_cwd, "three_classes", "train_test_valid_x_images_compressed_data_array_224.npz")
train_test_valid_y_labels_data = os.path.join(image_data_cwd, "three_classes", "train_test_valid_y_labels_compressed_array_224.npy")

# %%
# Importing required libraries

from tensorflow import keras
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import BatchNormalization, Activation
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import tensorflow as tf
import numpy as np
import warnings
import cv2
import re
import os

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Helper functions

# %%
def get_cwd_files(path):

  ignore_files = [".gitkeep", ".gitignore"]
  path_files = os.listdir(path)
  path_files = [file for file in path_files if file not in ignore_files]

  return path_files

# %%
def get_image_data(image_data_process_directory, image_resize_value):

  # Classes for our prediction
  classification_classes = ["Healthy_bones", "Fractured_bones", "Bones_beyond_repair"]
  classification_classes_dict = {1:"Healthy_bones", 2:"Fractured_bones", 3:"Bones_beyond_repair"}
  # Set Image size
  img_size = image_resize_value

  #flag_counter = 0
  # Processing image to array
  #data = []
  image_data = []
  label_data = []
  for each_class in classification_classes:
    #flag_counter = 0
    class_category_number = classification_classes.index(each_class)
    bone_class_img_path = os.path.join(image_data_process_directory, each_class)
    #print(bone_class_img_path)
    bone_images = get_cwd_files(bone_class_img_path)
    for bone_image in bone_images:
      
      '''
      if flag_counter == 50:
        break
      flag_counter += 1'''

      bone_image_path = os.path.join(bone_class_img_path, bone_image)
      #print(bone_image_path)
      try:
        x_ray_image = load_img(bone_image_path, target_size=(img_size, img_size))
        x_ray_image = img_to_array(x_ray_image)
        image_data.append(x_ray_image)
        label_data.append(class_category_number)
        #print(x_ray_image.shape)
        #data.append([x_ray_image, class_category_number])
      except:
        print("Some error occured in fetching data!")

  
  #data = np.array(data)
  image_data = np.array(image_data)
  label_data = np.array(label_data) 
  
  return image_data, label_data

# %% [markdown]
# ## Main Program

# %% [markdown]
# Pre processing images to arrays and storing them is done only for the first run and for subsequent runs load the saved array images files for further work to reduce time.

# %%
# Processing train data images
#train_test_valid_x, train_test_valid_y = get_image_data(dataset_cwd, image_resize_value = 224)

# %% [markdown]
# ## Storing values of the image processed array data in csv files

# %%
# Storing Train_test_valid image array values

# For train_test_valid_x compressed values
#np.savez_compressed("train_test_valid_x_images_compressed_data_array_224", train_test_valid_array = train_test_valid_x)

# For train_test_valid_y compressed values
#np.save("train_test_valid_y_labels_compressed_array_224", train_test_valid_y)

# %% [markdown]
# ## Loading Image arrays from the saved files

# %%
# Loading Train image compressed array values

# For train_x values
model_train_test_valid_x = np.load(train_test_valid_x_image_data)["train_test_valid_array"]

# For train_y values
model_train_test_valid_y = np.load(train_test_valid_y_labels_data)

# %%
# Creating train and test dataset
train_valid_x, model_test_x, train_valid_y, model_test_y = train_test_split(model_train_test_valid_x, model_train_test_valid_y, random_state = 42, stratify = model_train_test_valid_y, test_size = 0.10)

# %%
# Creating train and test dataset
model_train_x, model_valid_x, model_train_y, model_valid_y = train_test_split(train_valid_x, train_valid_y, random_state = 42, stratify = train_valid_y, test_size = 0.15)

# %%
# Removing specific variables from runtime to save RAM
del model_train_test_valid_x, model_train_test_valid_y, train_valid_x, train_valid_y

# %%
# Normalizing values
model_train_x, model_train_y = model_train_x/255, model_train_y
model_test_x, model_test_y = model_test_x/255, model_test_y
model_valid_x, model_valid_y = model_valid_x/255, model_valid_y

# %% [markdown]
# ### Data Visualization

# %%
## visualizing some training data
sample_training_data = list(model_train_x[0:50])
sample_training_label = list(model_train_y[0:50])
label_mapping = {0:"Healthy_bones", 1:"Fractured_bones", 2:"Bones_beyond_repair"}

plt.figure(figsize=(15,30))
for i in range(50):
  plt.subplot(10, 5, i + 1)
  img_pil = array_to_img(sample_training_data[i])
  plt.imshow(img_pil, interpolation='nearest')
  plt.title(label_mapping[sample_training_label[i]])
  plt.axis("off")

# %% [markdown]
# ## Hyperparameters for Data Augmentation

# %%
# Hyperparameters for Imagedatagenerator
model_shear_range = 0.2           # Image angular deformation range
model_zoom_range = 0.2            # Image zoom in/out range
model_brightness_range = [0.9,1.2]    # Brightness change range (0.9 to 1.2)
model_rotation_range = 30         # Angular change range
model_width_shift_range = 0.2     # Horizontal shift range
model_height_shift_range = 0.2    # Vertical shift range

# %% [markdown]
# ### Data Augmentation Initilization

# %%
# Image generator for training images
train_gen = ImageDataGenerator(
    rotation_range = model_rotation_range,
    #brightness_range = model_brightness_range,
    #width_shift_range = model_width_shift_range,
    #height_shift_range = model_height_shift_range,
    #zoom_range = model_zoom_range,
    #shear_range = model_shear_range,
    horizontal_flip = True,
    vertical_flip=True,
    #fill_mode = "constant",
    #cval = 0.0  # fill with black color for any blank spaces present after image shift
)

# Image generator fo validation images
valid_gen = ImageDataGenerator()  # No parameters

# %% [markdown]
# ### Data Augmentation

# %%
# Fitting image generator models to datasets 
train_gen.fit(model_train_x)
valid_gen.fit(model_valid_x)

# Creating iter variables for model compile flow
train_iter = train_gen.flow(model_train_x, model_train_y, batch_size = 32)
valid_iter = valid_gen.flow(model_valid_x, model_valid_y, batch_size = 8, shuffle = False)

# %% [markdown]
# ## Hyperparameters for model building

# %%
# Model hyperparameters
model_accuracy = ["acc", "mse"]

# When using all 3 classes (healthy bones, fractured bones and bones beyond repair), then this categorical cross entropy loss
# Using Sparse categorical instead of just categorical as the classes here are considered to be mutually exclusive and hence sparse categorical
# If the sample could have multiple classes or labels (not completely mutually exclusive), then use categorical.
model_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Now as we are working with 2 class currently (healthy bones and fractured bones) we will use binary crossentrophy loss
#model_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Model checkpoints directory as per version of models created (This is version 1)
model_checkpoints_dir = os.path.join(model_checkpoints_cwd, "v1")

model_lr = 0.000001  # 0.000001
model_l2_regularizer_lambda = 0.000001
model_optimizer = Adam(learning_rate = model_lr)
#model_optimizer = RMSprop(learning_rate = model_lr)
model_epochs = 100
model_callbacks = [
                ModelCheckpoint(model_checkpoints_dir, monitor = "val_loss", save_best_only=True, mode="min",options=None),
                EarlyStopping(monitor="val_loss",min_delta=1e-4,patience=8,verbose=1, mode="min",restore_best_weights=True),
                ReduceLROnPlateau(monitor="val_loss",min_delta=1e-4, factor=0.1, patience=3, verbose=1, min_lr=0.0001,mode="min")                
                ]

# After an intial run, we understood as the classes are heavily imbalanced (maybe due to imbalanced dataset or lack of features from the other unpredicted class),
# We use assigning class weights option to let our model train from all classes uniquely, later we will also try to increase our dataset for the better classification
weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(model_train_y), y = model_train_y)
model_class_weights = dict(zip(np.unique(model_train_y), weights))

# %% [markdown]
# ### Model Building

# %%
# Function for getting pre trained model
def get_pre_trained_model_VGG19():

  try:
    # Importing model excluding the fully connected layer at the top
    model = VGG19(include_top=False, weights = 'imagenet', input_shape=(224, 224, 3))
  
  except:
    print("Pre-trained model Initialization failed !!")

  # Freezing the pretrained model weights so that they wont be updated during back propagation
  for layer in model.layers:
    layer.trainable = False

  last_output = model.layers[-1].output

  return model, last_output

# %%
# Model Architecture

cnn_model, last_output = get_pre_trained_model_VGG19()

flattened_last_layer_output = Flatten()(last_output)
dense_layer_1 = Dense(512, kernel_initializer = 'he_uniform', activation='relu')(flattened_last_layer_output)
dense_layer_2 = Dense(128, kernel_initializer = 'he_uniform', activation='relu')(dense_layer_1)
dropout_output = Dropout(0.2)(dense_layer_2)

final_layer = Dense(3, activation="softmax")(dropout_output)
cnn_model = Model(cnn_model.input, final_layer)

cnn_model.compile(optimizer = model_optimizer, loss = model_loss, metrics = model_accuracy)
cnn_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 32,936,003
# Trainable params: 12,911,619
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Model Plot
plot_model(cnn_model,show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

# %%
# Model fit
history = cnn_model.fit(train_iter, validation_data=valid_iter, steps_per_epoch=len(model_train_x)/32, epochs=model_epochs, callbacks=model_callbacks)
# Out:
# Epoch 1/100
# 89/88 [==============================] - ETA: 0s - loss: 1.0709 - acc: 0.4220 - mse: 0.8295INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 77s 688ms/step - loss: 1.0709 - acc: 0.4220 - mse: 0.8295 - val_loss: 0.9933 - val_acc: 0.4480 - val_mse: 0.8214 - lr: 1.0000e-06
# Epoch 2/100
# 89/88 [==============================] - ETA: 0s - loss: 0.9995 - acc: 0.4560 - mse: 0.8296INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 57s 640ms/step - loss: 0.9995 - acc: 0.4560 - mse: 0.8296 - val_loss: 0.9406 - val_acc: 0.4860 - val_mse: 0.8244 - lr: 1.0000e-06
# Epoch 3/100
# 89/88 [==============================] - ETA: 0s - loss: 0.9477 - acc: 0.4995 - mse: 0.8337INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 613ms/step - loss: 0.9477 - acc: 0.4995 - mse: 0.8337 - val_loss: 0.9088 - val_acc: 0.5300 - val_mse: 0.8256 - lr: 1.0000e-06
# Epoch 4/100
# 89/88 [==============================] - ETA: 0s - loss: 0.9097 - acc: 0.5267 - mse: 0.8357INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 610ms/step - loss: 0.9097 - acc: 0.5267 - mse: 0.8357 - val_loss: 0.8803 - val_acc: 0.5240 - val_mse: 0.8310 - lr: 1.0000e-06
# Epoch 5/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8868 - acc: 0.5401 - mse: 0.8391INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 611ms/step - loss: 0.8868 - acc: 0.5401 - mse: 0.8391 - val_loss: 0.8621 - val_acc: 0.5520 - val_mse: 0.8344 - lr: 1.0000e-06
# Epoch 6/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8636 - acc: 0.5508 - mse: 0.8427INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 627ms/step - loss: 0.8636 - acc: 0.5508 - mse: 0.8427 - val_loss: 0.8471 - val_acc: 0.5480 - val_mse: 0.8387 - lr: 1.0000e-06
# Epoch 7/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8502 - acc: 0.5433 - mse: 0.8455INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.8502 - acc: 0.5433 - mse: 0.8455 - val_loss: 0.8382 - val_acc: 0.5400 - val_mse: 0.8399 - lr: 1.0000e-06
# Epoch 8/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8406 - acc: 0.5564 - mse: 0.8468INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 616ms/step - loss: 0.8406 - acc: 0.5564 - mse: 0.8468 - val_loss: 0.8270 - val_acc: 0.5380 - val_mse: 0.8430 - lr: 1.0000e-06
# Epoch 9/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8290 - acc: 0.5663 - mse: 0.8501INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 631ms/step - loss: 0.8290 - acc: 0.5663 - mse: 0.8501 - val_loss: 0.8190 - val_acc: 0.5480 - val_mse: 0.8457 - lr: 1.0000e-06
# Epoch 10/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8192 - acc: 0.5656 - mse: 0.8517INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 618ms/step - loss: 0.8192 - acc: 0.5656 - mse: 0.8517 - val_loss: 0.8108 - val_acc: 0.5440 - val_mse: 0.8476 - lr: 1.0000e-06
# Epoch 11/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8101 - acc: 0.5837 - mse: 0.8529INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 613ms/step - loss: 0.8101 - acc: 0.5837 - mse: 0.8529 - val_loss: 0.8081 - val_acc: 0.5700 - val_mse: 0.8508 - lr: 1.0000e-06
# Epoch 12/100
# 89/88 [==============================] - ETA: 0s - loss: 0.8062 - acc: 0.5745 - mse: 0.8547INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 614ms/step - loss: 0.8062 - acc: 0.5745 - mse: 0.8547 - val_loss: 0.7996 - val_acc: 0.5640 - val_mse: 0.8509 - lr: 1.0000e-06
# Epoch 13/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7973 - acc: 0.5897 - mse: 0.8547INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 622ms/step - loss: 0.7973 - acc: 0.5897 - mse: 0.8547 - val_loss: 0.7949 - val_acc: 0.5680 - val_mse: 0.8506 - lr: 1.0000e-06
# Epoch 14/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7857 - acc: 0.5918 - mse: 0.8566INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 605ms/step - loss: 0.7857 - acc: 0.5918 - mse: 0.8566 - val_loss: 0.7867 - val_acc: 0.5760 - val_mse: 0.8539 - lr: 1.0000e-06
# Epoch 15/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7847 - acc: 0.5883 - mse: 0.8580INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 607ms/step - loss: 0.7847 - acc: 0.5883 - mse: 0.8580 - val_loss: 0.7845 - val_acc: 0.5780 - val_mse: 0.8534 - lr: 1.0000e-06
# Epoch 16/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7785 - acc: 0.5978 - mse: 0.8592INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 53s 603ms/step - loss: 0.7785 - acc: 0.5978 - mse: 0.8592 - val_loss: 0.7781 - val_acc: 0.5880 - val_mse: 0.8564 - lr: 1.0000e-06
# Epoch 17/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7802 - acc: 0.5886 - mse: 0.8595INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 610ms/step - loss: 0.7802 - acc: 0.5886 - mse: 0.8595 - val_loss: 0.7770 - val_acc: 0.5760 - val_mse: 0.8553 - lr: 1.0000e-06
# Epoch 18/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7782 - acc: 0.5950 - mse: 0.8603INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 606ms/step - loss: 0.7782 - acc: 0.5950 - mse: 0.8603 - val_loss: 0.7682 - val_acc: 0.5960 - val_mse: 0.8570 - lr: 1.0000e-06
# Epoch 19/100
# 88/88 [==============================] - 50s 566ms/step - loss: 0.7630 - acc: 0.6120 - mse: 0.8616 - val_loss: 0.7683 - val_acc: 0.5960 - val_mse: 0.8567 - lr: 1.0000e-06
# Epoch 20/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7657 - acc: 0.6098 - mse: 0.8613INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 608ms/step - loss: 0.7657 - acc: 0.6098 - mse: 0.8613 - val_loss: 0.7628 - val_acc: 0.6100 - val_mse: 0.8600 - lr: 1.0000e-06
# Epoch 21/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7609 - acc: 0.6084 - mse: 0.8629INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 618ms/step - loss: 0.7609 - acc: 0.6084 - mse: 0.8629 - val_loss: 0.7595 - val_acc: 0.6100 - val_mse: 0.8602 - lr: 1.0000e-06
# Epoch 22/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7562 - acc: 0.6155 - mse: 0.8637INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 613ms/step - loss: 0.7562 - acc: 0.6155 - mse: 0.8637 - val_loss: 0.7565 - val_acc: 0.6020 - val_mse: 0.8606 - lr: 1.0000e-06
# Epoch 23/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7532 - acc: 0.6233 - mse: 0.8647INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 612ms/step - loss: 0.7532 - acc: 0.6233 - mse: 0.8647 - val_loss: 0.7549 - val_acc: 0.6000 - val_mse: 0.8603 - lr: 1.0000e-06
# Epoch 24/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7455 - acc: 0.6219 - mse: 0.8644INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 619ms/step - loss: 0.7455 - acc: 0.6219 - mse: 0.8644 - val_loss: 0.7525 - val_acc: 0.5960 - val_mse: 0.8613 - lr: 1.0000e-06
# Epoch 25/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7494 - acc: 0.6197 - mse: 0.8656INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 613ms/step - loss: 0.7494 - acc: 0.6197 - mse: 0.8656 - val_loss: 0.7481 - val_acc: 0.6060 - val_mse: 0.8622 - lr: 1.0000e-06
# Epoch 26/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7423 - acc: 0.6190 - mse: 0.8659INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 619ms/step - loss: 0.7423 - acc: 0.6190 - mse: 0.8659 - val_loss: 0.7460 - val_acc: 0.6060 - val_mse: 0.8640 - lr: 1.0000e-06
# Epoch 27/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7457 - acc: 0.6219 - mse: 0.8672INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 620ms/step - loss: 0.7457 - acc: 0.6219 - mse: 0.8672 - val_loss: 0.7425 - val_acc: 0.6100 - val_mse: 0.8644 - lr: 1.0000e-06
# Epoch 28/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7347 - acc: 0.6243 - mse: 0.8676INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 629ms/step - loss: 0.7347 - acc: 0.6243 - mse: 0.8676 - val_loss: 0.7406 - val_acc: 0.6180 - val_mse: 0.8663 - lr: 1.0000e-06
# Epoch 29/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7230 - acc: 0.6335 - mse: 0.8677INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 631ms/step - loss: 0.7230 - acc: 0.6335 - mse: 0.8677 - val_loss: 0.7393 - val_acc: 0.6100 - val_mse: 0.8665 - lr: 1.0000e-06
# Epoch 30/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7366 - acc: 0.6258 - mse: 0.8683INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 57s 639ms/step - loss: 0.7366 - acc: 0.6258 - mse: 0.8683 - val_loss: 0.7367 - val_acc: 0.6240 - val_mse: 0.8660 - lr: 1.0000e-06
# Epoch 31/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7262 - acc: 0.6321 - mse: 0.8695INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 627ms/step - loss: 0.7262 - acc: 0.6321 - mse: 0.8695 - val_loss: 0.7340 - val_acc: 0.6160 - val_mse: 0.8677 - lr: 1.0000e-06
# Epoch 32/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7214 - acc: 0.6431 - mse: 0.8695INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 626ms/step - loss: 0.7214 - acc: 0.6431 - mse: 0.8695 - val_loss: 0.7326 - val_acc: 0.6160 - val_mse: 0.8669 - lr: 1.0000e-06
# Epoch 33/100
# 88/88 [==============================] - 50s 566ms/step - loss: 0.7237 - acc: 0.6427 - mse: 0.8703 - val_loss: 0.7326 - val_acc: 0.6180 - val_mse: 0.8694 - lr: 1.0000e-06
# Epoch 34/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7091 - acc: 0.6491 - mse: 0.8706INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 53s 601ms/step - loss: 0.7091 - acc: 0.6491 - mse: 0.8706 - val_loss: 0.7304 - val_acc: 0.6280 - val_mse: 0.8683 - lr: 1.0000e-06
# Epoch 35/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7165 - acc: 0.6360 - mse: 0.8705INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 608ms/step - loss: 0.7165 - acc: 0.6360 - mse: 0.8705 - val_loss: 0.7280 - val_acc: 0.6200 - val_mse: 0.8692 - lr: 1.0000e-06
# Epoch 36/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7157 - acc: 0.6395 - mse: 0.8711INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 616ms/step - loss: 0.7157 - acc: 0.6395 - mse: 0.8711 - val_loss: 0.7272 - val_acc: 0.6240 - val_mse: 0.8701 - lr: 1.0000e-06
# Epoch 37/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7129 - acc: 0.6449 - mse: 0.8720INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 607ms/step - loss: 0.7129 - acc: 0.6449 - mse: 0.8720 - val_loss: 0.7268 - val_acc: 0.6200 - val_mse: 0.8705 - lr: 1.0000e-06
# Epoch 38/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7068 - acc: 0.6463 - mse: 0.8724INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 620ms/step - loss: 0.7068 - acc: 0.6463 - mse: 0.8724 - val_loss: 0.7233 - val_acc: 0.6320 - val_mse: 0.8677 - lr: 1.0000e-06
# Epoch 39/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7077 - acc: 0.6495 - mse: 0.8725INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 608ms/step - loss: 0.7077 - acc: 0.6495 - mse: 0.8725 - val_loss: 0.7205 - val_acc: 0.6300 - val_mse: 0.8690 - lr: 1.0000e-06
# Epoch 40/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7048 - acc: 0.6516 - mse: 0.8726INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 617ms/step - loss: 0.7048 - acc: 0.6516 - mse: 0.8726 - val_loss: 0.7200 - val_acc: 0.6280 - val_mse: 0.8689 - lr: 1.0000e-06
# Epoch 41/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7124 - acc: 0.6388 - mse: 0.8720INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 610ms/step - loss: 0.7124 - acc: 0.6388 - mse: 0.8720 - val_loss: 0.7188 - val_acc: 0.6320 - val_mse: 0.8705 - lr: 1.0000e-06
# Epoch 42/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6989 - acc: 0.6576 - mse: 0.8737INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 633ms/step - loss: 0.6989 - acc: 0.6576 - mse: 0.8737 - val_loss: 0.7163 - val_acc: 0.6280 - val_mse: 0.8699 - lr: 1.0000e-06
# Epoch 43/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7023 - acc: 0.6484 - mse: 0.8745INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 613ms/step - loss: 0.7023 - acc: 0.6484 - mse: 0.8745 - val_loss: 0.7153 - val_acc: 0.6300 - val_mse: 0.8719 - lr: 1.0000e-06
# Epoch 44/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6965 - acc: 0.6537 - mse: 0.8733INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 610ms/step - loss: 0.6965 - acc: 0.6537 - mse: 0.8733 - val_loss: 0.7135 - val_acc: 0.6380 - val_mse: 0.8720 - lr: 1.0000e-06
# Epoch 45/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7010 - acc: 0.6498 - mse: 0.8754INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.7010 - acc: 0.6498 - mse: 0.8754 - val_loss: 0.7121 - val_acc: 0.6320 - val_mse: 0.8705 - lr: 1.0000e-06
# Epoch 46/100
# 89/88 [==============================] - ETA: 0s - loss: 0.7029 - acc: 0.6537 - mse: 0.8745INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 634ms/step - loss: 0.7029 - acc: 0.6537 - mse: 0.8745 - val_loss: 0.7099 - val_acc: 0.6360 - val_mse: 0.8708 - lr: 1.0000e-06
# Epoch 47/100
# 88/88 [==============================] - 52s 588ms/step - loss: 0.7024 - acc: 0.6548 - mse: 0.8744 - val_loss: 0.7105 - val_acc: 0.6260 - val_mse: 0.8746 - lr: 1.0000e-06
# Epoch 48/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6925 - acc: 0.6565 - mse: 0.8746INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 620ms/step - loss: 0.6925 - acc: 0.6565 - mse: 0.8746 - val_loss: 0.7076 - val_acc: 0.6360 - val_mse: 0.8725 - lr: 1.0000e-06
# Epoch 49/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6923 - acc: 0.6548 - mse: 0.8761INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 622ms/step - loss: 0.6923 - acc: 0.6548 - mse: 0.8761 - val_loss: 0.7057 - val_acc: 0.6400 - val_mse: 0.8720 - lr: 1.0000e-06
# Epoch 50/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6822 - acc: 0.6696 - mse: 0.8759INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 638ms/step - loss: 0.6822 - acc: 0.6696 - mse: 0.8759 - val_loss: 0.7053 - val_acc: 0.6340 - val_mse: 0.8728 - lr: 1.0000e-06
# Epoch 51/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6886 - acc: 0.6583 - mse: 0.8764INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 619ms/step - loss: 0.6886 - acc: 0.6583 - mse: 0.8764 - val_loss: 0.7037 - val_acc: 0.6400 - val_mse: 0.8732 - lr: 1.0000e-06
# Epoch 52/100
# 88/88 [==============================] - 51s 571ms/step - loss: 0.6853 - acc: 0.6615 - mse: 0.8759 - val_loss: 0.7068 - val_acc: 0.6380 - val_mse: 0.8774 - lr: 1.0000e-06
# Epoch 53/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6889 - acc: 0.6604 - mse: 0.8770INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 612ms/step - loss: 0.6889 - acc: 0.6604 - mse: 0.8770 - val_loss: 0.7029 - val_acc: 0.6320 - val_mse: 0.8746 - lr: 1.0000e-06
# Epoch 54/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6834 - acc: 0.6632 - mse: 0.8761INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 610ms/step - loss: 0.6834 - acc: 0.6632 - mse: 0.8761 - val_loss: 0.7012 - val_acc: 0.6520 - val_mse: 0.8730 - lr: 1.0000e-06
# Epoch 55/100
# 88/88 [==============================] - 51s 571ms/step - loss: 0.6843 - acc: 0.6693 - mse: 0.8764 - val_loss: 0.7043 - val_acc: 0.6440 - val_mse: 0.8776 - lr: 1.0000e-06
# Epoch 56/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6821 - acc: 0.6664 - mse: 0.8777INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 606ms/step - loss: 0.6821 - acc: 0.6664 - mse: 0.8777 - val_loss: 0.7000 - val_acc: 0.6440 - val_mse: 0.8752 - lr: 1.0000e-06
# Epoch 57/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6805 - acc: 0.6597 - mse: 0.8780INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 612ms/step - loss: 0.6805 - acc: 0.6597 - mse: 0.8780 - val_loss: 0.6986 - val_acc: 0.6440 - val_mse: 0.8737 - lr: 1.0000e-06
# Epoch 58/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6815 - acc: 0.6686 - mse: 0.8773INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 615ms/step - loss: 0.6815 - acc: 0.6686 - mse: 0.8773 - val_loss: 0.6975 - val_acc: 0.6380 - val_mse: 0.8748 - lr: 1.0000e-06
# Epoch 59/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6762 - acc: 0.6671 - mse: 0.8771INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 606ms/step - loss: 0.6762 - acc: 0.6671 - mse: 0.8771 - val_loss: 0.6967 - val_acc: 0.6440 - val_mse: 0.8756 - lr: 1.0000e-06
# Epoch 60/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6693 - acc: 0.6728 - mse: 0.8779INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 609ms/step - loss: 0.6693 - acc: 0.6728 - mse: 0.8779 - val_loss: 0.6953 - val_acc: 0.6580 - val_mse: 0.8745 - lr: 1.0000e-06
# Epoch 61/100
# 88/88 [==============================] - 50s 566ms/step - loss: 0.6740 - acc: 0.6703 - mse: 0.8790 - val_loss: 0.6954 - val_acc: 0.6380 - val_mse: 0.8766 - lr: 1.0000e-06
# Epoch 62/100
# 88/88 [==============================] - 49s 556ms/step - loss: 0.6735 - acc: 0.6756 - mse: 0.8785 - val_loss: 0.6959 - val_acc: 0.6420 - val_mse: 0.8786 - lr: 1.0000e-06
# Epoch 63/100
# 88/88 [==============================] - 50s 560ms/step - loss: 0.6740 - acc: 0.6632 - mse: 0.8788 - val_loss: 0.6964 - val_acc: 0.6500 - val_mse: 0.8794 - lr: 1.0000e-06
# Epoch 64/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6675 - acc: 0.6788 - mse: 0.8798INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 53s 602ms/step - loss: 0.6675 - acc: 0.6788 - mse: 0.8798 - val_loss: 0.6905 - val_acc: 0.6580 - val_mse: 0.8760 - lr: 1.0000e-06
# Epoch 65/100
# 88/88 [==============================] - 50s 566ms/step - loss: 0.6697 - acc: 0.6625 - mse: 0.8798 - val_loss: 0.6907 - val_acc: 0.6500 - val_mse: 0.8771 - lr: 1.0000e-06
# Epoch 66/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6724 - acc: 0.6671 - mse: 0.8800INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 57s 640ms/step - loss: 0.6724 - acc: 0.6671 - mse: 0.8800 - val_loss: 0.6904 - val_acc: 0.6480 - val_mse: 0.8761 - lr: 1.0000e-06
# Epoch 67/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6632 - acc: 0.6855 - mse: 0.8807INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 611ms/step - loss: 0.6632 - acc: 0.6855 - mse: 0.8807 - val_loss: 0.6902 - val_acc: 0.6540 - val_mse: 0.8767 - lr: 1.0000e-06
# Epoch 68/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6662 - acc: 0.6788 - mse: 0.8798INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 617ms/step - loss: 0.6662 - acc: 0.6788 - mse: 0.8798 - val_loss: 0.6886 - val_acc: 0.6500 - val_mse: 0.8772 - lr: 1.0000e-06
# Epoch 69/100
# 88/88 [==============================] - 51s 579ms/step - loss: 0.6616 - acc: 0.6852 - mse: 0.8793 - val_loss: 0.6917 - val_acc: 0.6540 - val_mse: 0.8805 - lr: 1.0000e-06
# Epoch 70/100
# 88/88 [==============================] - 52s 585ms/step - loss: 0.6654 - acc: 0.6788 - mse: 0.8805 - val_loss: 0.6945 - val_acc: 0.6540 - val_mse: 0.8817 - lr: 1.0000e-06
# Epoch 71/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6662 - acc: 0.6728 - mse: 0.8800INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 615ms/step - loss: 0.6662 - acc: 0.6728 - mse: 0.8800 - val_loss: 0.6873 - val_acc: 0.6540 - val_mse: 0.8789 - lr: 1.0000e-06
# Epoch 72/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6599 - acc: 0.6823 - mse: 0.8802INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.6599 - acc: 0.6823 - mse: 0.8802 - val_loss: 0.6855 - val_acc: 0.6520 - val_mse: 0.8794 - lr: 1.0000e-06
# Epoch 73/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6605 - acc: 0.6756 - mse: 0.8809INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 614ms/step - loss: 0.6605 - acc: 0.6756 - mse: 0.8809 - val_loss: 0.6843 - val_acc: 0.6560 - val_mse: 0.8768 - lr: 1.0000e-06
# Epoch 74/100
# 88/88 [==============================] - 50s 570ms/step - loss: 0.6587 - acc: 0.6919 - mse: 0.8808 - val_loss: 0.6846 - val_acc: 0.6480 - val_mse: 0.8790 - lr: 1.0000e-06
# Epoch 75/100
# 88/88 [==============================] - 51s 573ms/step - loss: 0.6612 - acc: 0.6891 - mse: 0.8807 - val_loss: 0.6858 - val_acc: 0.6560 - val_mse: 0.8803 - lr: 1.0000e-06
# Epoch 76/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6588 - acc: 0.6841 - mse: 0.8823INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.6588 - acc: 0.6841 - mse: 0.8823 - val_loss: 0.6828 - val_acc: 0.6640 - val_mse: 0.8776 - lr: 1.0000e-06
# Epoch 77/100
# 88/88 [==============================] - 51s 579ms/step - loss: 0.6531 - acc: 0.6827 - mse: 0.8819 - val_loss: 0.6829 - val_acc: 0.6660 - val_mse: 0.8778 - lr: 1.0000e-06
# Epoch 78/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6544 - acc: 0.6869 - mse: 0.8823INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 54s 615ms/step - loss: 0.6544 - acc: 0.6869 - mse: 0.8823 - val_loss: 0.6824 - val_acc: 0.6660 - val_mse: 0.8776 - lr: 1.0000e-06
# Epoch 79/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6510 - acc: 0.6838 - mse: 0.8824INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 636ms/step - loss: 0.6510 - acc: 0.6838 - mse: 0.8824 - val_loss: 0.6804 - val_acc: 0.6560 - val_mse: 0.8788 - lr: 1.0000e-06
# Epoch 80/100
# 88/88 [==============================] - 52s 582ms/step - loss: 0.6499 - acc: 0.6774 - mse: 0.8824 - val_loss: 0.6822 - val_acc: 0.6640 - val_mse: 0.8777 - lr: 1.0000e-06
# Epoch 81/100
# 88/88 [==============================] - 51s 577ms/step - loss: 0.6499 - acc: 0.6944 - mse: 0.8827 - val_loss: 0.6850 - val_acc: 0.6560 - val_mse: 0.8850 - lr: 1.0000e-06
# Epoch 82/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6499 - acc: 0.6947 - mse: 0.8826INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 617ms/step - loss: 0.6499 - acc: 0.6947 - mse: 0.8826 - val_loss: 0.6786 - val_acc: 0.6640 - val_mse: 0.8777 - lr: 1.0000e-06
# Epoch 83/100
# 88/88 [==============================] - 51s 574ms/step - loss: 0.6480 - acc: 0.6990 - mse: 0.8826 - val_loss: 0.6796 - val_acc: 0.6540 - val_mse: 0.8816 - lr: 1.0000e-06
# Epoch 84/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6487 - acc: 0.6855 - mse: 0.8821INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.6487 - acc: 0.6855 - mse: 0.8821 - val_loss: 0.6775 - val_acc: 0.6520 - val_mse: 0.8826 - lr: 1.0000e-06
# Epoch 85/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6469 - acc: 0.6887 - mse: 0.8835INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 619ms/step - loss: 0.6469 - acc: 0.6887 - mse: 0.8835 - val_loss: 0.6760 - val_acc: 0.6660 - val_mse: 0.8792 - lr: 1.0000e-06
# Epoch 86/100
# 88/88 [==============================] - 51s 578ms/step - loss: 0.6442 - acc: 0.6972 - mse: 0.8840 - val_loss: 0.6770 - val_acc: 0.6640 - val_mse: 0.8823 - lr: 1.0000e-06
# Epoch 87/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6478 - acc: 0.6951 - mse: 0.8837INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.6478 - acc: 0.6951 - mse: 0.8837 - val_loss: 0.6750 - val_acc: 0.6620 - val_mse: 0.8819 - lr: 1.0000e-06
# Epoch 88/100
# 88/88 [==============================] - 51s 577ms/step - loss: 0.6455 - acc: 0.6845 - mse: 0.8842 - val_loss: 0.6765 - val_acc: 0.6600 - val_mse: 0.8800 - lr: 1.0000e-06
# Epoch 89/100
# 88/88 [==============================] - 50s 564ms/step - loss: 0.6405 - acc: 0.6866 - mse: 0.8845 - val_loss: 0.6774 - val_acc: 0.6480 - val_mse: 0.8830 - lr: 1.0000e-06
# Epoch 90/100
# 88/88 [==============================] - 50s 563ms/step - loss: 0.6380 - acc: 0.6919 - mse: 0.8845 - val_loss: 0.6754 - val_acc: 0.6660 - val_mse: 0.8815 - lr: 1.0000e-06
# Epoch 91/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6453 - acc: 0.6866 - mse: 0.8836INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 53s 604ms/step - loss: 0.6453 - acc: 0.6866 - mse: 0.8836 - val_loss: 0.6740 - val_acc: 0.6620 - val_mse: 0.8802 - lr: 1.0000e-06
# Epoch 92/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6385 - acc: 0.6969 - mse: 0.8848INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 56s 628ms/step - loss: 0.6385 - acc: 0.6969 - mse: 0.8848 - val_loss: 0.6722 - val_acc: 0.6700 - val_mse: 0.8813 - lr: 1.0000e-06
# Epoch 93/100
# 88/88 [==============================] - 52s 582ms/step - loss: 0.6434 - acc: 0.6877 - mse: 0.8839 - val_loss: 0.6751 - val_acc: 0.6640 - val_mse: 0.8835 - lr: 1.0000e-06
# Epoch 94/100
# 88/88 [==============================] - 51s 576ms/step - loss: 0.6317 - acc: 0.6990 - mse: 0.8866 - val_loss: 0.6743 - val_acc: 0.6580 - val_mse: 0.8858 - lr: 1.0000e-06
# Epoch 95/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6401 - acc: 0.6983 - mse: 0.8851INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 619ms/step - loss: 0.6401 - acc: 0.6983 - mse: 0.8851 - val_loss: 0.6701 - val_acc: 0.6720 - val_mse: 0.8804 - lr: 1.0000e-06
# Epoch 96/100
# 88/88 [==============================] - 51s 575ms/step - loss: 0.6435 - acc: 0.6933 - mse: 0.8847 - val_loss: 0.6738 - val_acc: 0.6500 - val_mse: 0.8851 - lr: 1.0000e-06
# Epoch 97/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6309 - acc: 0.6997 - mse: 0.8856INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 617ms/step - loss: 0.6309 - acc: 0.6997 - mse: 0.8856 - val_loss: 0.6701 - val_acc: 0.6840 - val_mse: 0.8821 - lr: 1.0000e-06
# Epoch 98/100
# 89/88 [==============================] - ETA: 0s - loss: 0.6278 - acc: 0.6951 - mse: 0.8859INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 88/88 [==============================] - 55s 621ms/step - loss: 0.6278 - acc: 0.6951 - mse: 0.8859 - val_loss: 0.6694 - val_acc: 0.6700 - val_mse: 0.8814 - lr: 1.0000e-06
# Epoch 99/100
# 88/88 [==============================] - 51s 578ms/step - loss: 0.6345 - acc: 0.6898 - mse: 0.8855 - val_loss: 0.6700 - val_acc: 0.6620 - val_mse: 0.8840 - lr: 1.0000e-06
# Epoch 100/100
# 88/88 [==============================] - 51s 573ms/step - loss: 0.6379 - acc: 0.6930 - mse: 0.8846 - val_loss: 0.6712 - val_acc: 0.6620 - val_mse: 0.8852 - lr: 1.0000e-06

# %%
# Save model
keras.models.save_model(cnn_model, "Transfer_learning_model_v3.h5", save_format="h5")

# %%
# Model History Plot
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
mse = history.history['mse']
val_mse = history.history['val_mse']
epochs_range = range(len(history.history['loss']))

plt.figure(0)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, acc, 'r', label='Training Accuracy')
plt.plot(epochs_range, val_acc, 'g', label='Validation Accuracy')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.title('Training vs Validation Accuracy')

plt.figure(1)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.title('Training vs Validation Loss')

plt.figure(2)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, mse, label='Training mse')
plt.plot(epochs_range, val_mse, label='Validation mse')
plt.xlabel("Num of Epochs")
plt.ylabel("MSE")
plt.legend(loc='upper right')
plt.title('Training vs Validation MSE')

plt.show()

# %% [markdown]
# ## Prediction Stats

# %%
# Finding Prediction Error

# Since for now we are dealing with a binary classifciation problem (healthy bones and fractured bones), we use the following method
# Later when we continue working with all 3 classes (healthy bones, fractured bones and bones beyond repair), we will change the below maths accordingly
model_test_prediction_labels = cnn_model.predict(model_test_x)
model_test_prediction_list = []

for label_prediction in model_test_prediction_labels:
    model_test_prediction_list.append(np.argmax(label_prediction))


prediction_error = np.sum(np.not_equal(model_test_prediction_list, list(model_test_y))) / model_test_y.shape[0]
print(f"The prediction error for the model is {prediction_error}")
# Out:
# The prediction error for the model is 0.34324324324324323

# %% [markdown]
# #### The model prediction error should be close to zero. The above value will show how much the model needs more tuning and optimization in order to have prediction error closer to zero.

# %%
# Model testing stats
model_evaluation = cnn_model.evaluate(model_test_x, model_test_y, batch_size=8)
print(dict(zip(cnn_model.metrics_names, model_evaluation)))
# Out:
# 47/47 [==============================] - 9s 184ms/step - loss: 0.6753 - acc: 0.6568 - mse: 0.8875
# {'loss': 0.6752634644508362, 'acc': 0.6567567586898804, 'mse': 0.887455940246582}

# %% [markdown]
# ## Metric Stats

# %%
# Classification Report:
print('Classification Report: ')
print(classification_report(list(model_test_y), model_test_prediction_list, target_names=["0","1", "2"]))

# Confusion Matrix
print('Confusion Matrix: ')
cm = confusion_matrix(model_test_prediction_list, list(model_test_y))
plt.figure(figsize = (7.5,5))
sns.set(font_scale=1.4) # for label size
sns.heatmap(cm, annot=True, annot_kws={"size": 20},cmap="YlGnBu") # font size
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.90      0.75       150
#            1       0.63      0.33      0.44       141
#            2       0.71      0.77      0.74        79
#
#     accuracy                           0.66       370
#    macro avg       0.66      0.67      0.64       370
# weighted avg       0.65      0.66      0.63       370
#
# Confusion Matrix:
