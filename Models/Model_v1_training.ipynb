# %% [markdown]
# # CNN Model Building and Training Notebook
#
# ### This code is in developmental stage. Later will be translated for Azure Cloud implementation.
#
# ### To use this code, dataset has been stored in google drive and gdrive path is mounted for use in notebook.

# %%
try:
  import os, sys 
  #to be able to interact with Google Drive's operating system
  from google.colab import drive 
  #drive is a module that allows us use Python to interact with google drive
  drive.mount('/content/gdrive') 
  #mounting google drive allows us to work with its contents
  nb_path = '/content/notebooks'
  os.symlink('/content/gdrive/My Drive/Colab Notebooks', nb_path)
  sys.path.insert(0, nb_path)  # or append(nb_path)
  #The last three lines are what changes the path of the file.
except:
  print("Drive already mounted and ready to use!")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Drive already mounted and ready to use!

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %%
# Storing all required paths for later use

main_cwd = r'/content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging'
model_cwd = os.path.join(main_cwd, "Models")
dataset_cwd = os.path.join(main_cwd, "Datasets")
image_data_cwd = os.path.join(main_cwd, "Saved Image Data Arrays")
saved_models_cwd = os.path.join(main_cwd, "Saved_models")
model_checkpoints_cwd = os.path.join(main_cwd, "Model_check_points")
healthy_bones_dataset_cwd = os.path.join(dataset_cwd, "Healthy_bones")
fractured_bones_dataset_cwd = os.path.join(dataset_cwd, "Fractured_bones")
beyond_repair_bones_dataset_cwd = os.path.join(dataset_cwd, "Bones_beyond_repair")
train_test_valid_x_image_data = os.path.join(image_data_cwd, "train_test_valid_x_images_compressed_data_array_224.npz")
train_test_valid_y_labels_data = os.path.join(image_data_cwd, "train_test_valid_y_labels_compressed_array_224.npy")

# %%
# Importing required libraries

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import numpy as np
import warnings
import cv2
import re
import os

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Helper functions

# %%
def get_cwd_files(path):

  ignore_files = [".gitkeep", ".gitignore"]
  path_files = os.listdir(path)
  path_files = [file for file in path_files if file not in ignore_files]

  return path_files

# %%
def get_image_data(image_data_process_directory, image_resize_value):

  # Classes for our prediction
  classification_classes = ["Healthy_bones", "Fractured_bones"]
  classification_classes_dict = {1:"Healthy_bones", 2:"Fractured_bones", 3:"Bones_beyond_repair"}
  # Set Image size
  img_size = image_resize_value

  #flag_counter = 0
  # Processing image to array
  #data = []
  image_data = []
  label_data = []
  for each_class in classification_classes:
    #flag_counter = 0
    class_category_number = classification_classes.index(each_class)
    bone_class_img_path = os.path.join(image_data_process_directory, each_class)
    #print(bone_class_img_path)
    bone_images = get_cwd_files(bone_class_img_path)
    for bone_image in bone_images:
      
      '''
      if flag_counter == 50:
        break
      flag_counter += 1'''

      bone_image_path = os.path.join(bone_class_img_path, bone_image)
      #print(bone_image_path)
      try:
        x_ray_image = load_img(bone_image_path, target_size=(img_size, img_size))
        x_ray_image = img_to_array(x_ray_image)
        image_data.append(x_ray_image)
        label_data.append(class_category_number)
        #print(x_ray_image.shape)
        #data.append([x_ray_image, class_category_number])
      except:
        print("Some error occured in fetching data!")

  
  #data = np.array(data)
  image_data = np.array(image_data)
  label_data = np.array(label_data) 
  
  return image_data, label_data

# %% [markdown]
# ## Main Program

# %% [markdown]
# Pre processing images to arrays and storing them is done only for the first run and for subsequent runs load the saved array images files for further work to reduce time.

# %%
# Processing train data images
#train_test_valid_x, train_test_valid_y = get_image_data(dataset_cwd, image_resize_value = 224)

# %% [markdown]
# ## Storing values of the image processed array data in csv files

# %%
# Storing Train_test_valid image array values

# For train_test_valid_x compressed values
#np.savez_compressed("train_test_valid_x_images_compressed_data_array_224", train_test_valid_array = train_test_valid_x)

# For train_test_valid_y compressed values
#np.save("train_test_valid_y_labels_compressed_array_224", train_test_valid_y)

# %% [markdown]
# ## Loading Image arrays from the saved files

# %%
# Loading Train image compressed array values

# For train_x values
model_train_test_valid_x = np.load(train_test_valid_x_image_data)["train_test_valid_array"]

# For train_y values
model_train_test_valid_y = np.load(train_test_valid_y_labels_data)

# %%
# Creating train and test dataset
train_valid_x, model_test_x, train_valid_y, model_test_y = train_test_split(model_train_test_valid_x, model_train_test_valid_y, random_state = 42, stratify = model_train_test_valid_y, test_size = 0.10)

# %%
# Creating train and test dataset
model_train_x, model_valid_x, model_train_y, model_valid_y = train_test_split(train_valid_x, train_valid_y, random_state = 42, stratify = train_valid_y, test_size = 0.15)

# %%
# Removing specific variables from runtime to save RAM
del model_train_test_valid_x, model_train_test_valid_y, train_valid_x, train_valid_y

# %%
# Normalizing values
model_train_x, model_train_y = model_train_x/255, model_train_y
model_test_x, model_test_y = model_test_x/255, model_test_y
model_valid_x, model_valid_y = model_valid_x/255, model_valid_y

# %% [markdown]
# ## Hyperparameters for Data Augmentation

# %%
# Hyperparameters for Imagedatagenerator
model_shear_range = 0.2           # Image angular deformation range
model_zoom_range = 0.2            # Image zoom in/out range
model_brightness_range = [0.9,1.2]    # Brightness change range (0.9 to 1.2)
model_rotation_range = 30         # Angular change range
model_width_shift_range = 0.2     # Horizontal shift range
model_height_shift_range = 0.2    # Vertical shift range

# %% [markdown]
# ### Data Augmentation Initilization

# %%
# Image generator for training images
train_gen = ImageDataGenerator(
    rotation_range = model_rotation_range,
    #brightness_range = model_brightness_range,
    #width_shift_range = model_width_shift_range,
    #height_shift_range = model_height_shift_range,
    #zoom_range = model_zoom_range,
    #shear_range = model_shear_range,
    horizontal_flip = True,
    vertical_flip=True,
    #fill_mode = "constant",
    #cval = 0.0  # fill with black color for any blank spaces present after image shift
)

# Image generator fo validation images
valid_gen = ImageDataGenerator()  # No parameters

# %% [markdown]
# ### Data Augmentation

# %%
# Fitting image generator models to datasets 
train_gen.fit(model_train_x)
valid_gen.fit(model_valid_x)

# Creating iter variables for model compile flow
train_iter = train_gen.flow(model_train_x, model_train_y, batch_size = 32)
valid_iter = valid_gen.flow(model_valid_x, model_valid_y, batch_size = 8, shuffle = False)

# %% [markdown]
# ## Hyperparameters for model building

# %%
# Model hyperparameters
model_accuracy = ["acc", "mse"]

# When using all 3 classes (healthy bones, fractured bones and bones beyond repair), then this categorical cross entropy loss
# Using Sparse categorical instead of just categorical as the classes here are considered to be mutually exclusive and hence sparse categorical
# If the sample could have multiple classes or labels (not completely mutually exclusive), then use categorical.
#model_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Now as we are working with 2 class currently (healthy bones and fractured bones) we will use binary crossentrophy loss
model_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Model checkpoints directory as per version of models created (This is version 1)
model_checkpoints_dir = os.path.join(model_checkpoints_cwd, "v1")

model_lr = 0.001  # 0.000001
model_optimizer = Adam(learning_rate = model_lr)
model_epochs = 100
model_callbacks = [
                ModelCheckpoint(model_checkpoints_dir, monitor = "val_loss", save_best_only=True, mode="min",options=None),
                EarlyStopping(monitor="val_loss",min_delta=1e-4,patience=10,verbose=1, mode="min",restore_best_weights=True),
                ReduceLROnPlateau(monitor="val_loss",min_delta=1e-4, factor=0.1, patience=3, verbose=1, min_lr=0.0001,mode="min")                
                ]

# After an intial run, we understood as the classes are heavily imbalanced (maybe due to imbalanced dataset or lack of features from the other unpredicted class),
# We use assigning class weights option to let our model train from all classes uniquely, later we will also try to increase our dataset for the better classification
weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(model_train_y), y = model_train_y)
model_class_weights = dict(zip(np.unique(model_train_y), weights))

# %% [markdown]
# ### Model Building

# %%
# CNN Architecture
### adding sequential model ,add a bunch of conv,maxpool,dropout ,flatten it and then eventually add dense layers for all classes.

cnn_model = Sequential()
cnn_model.add(Conv2D(32, 3,padding="same", activation="relu", input_shape=(224,224,3)))
cnn_model.add(MaxPool2D())  # Default is (2x2)

cnn_model.add(Conv2D(32, 3, padding="same", activation="relu"))
cnn_model.add(MaxPool2D())

cnn_model.add(Conv2D(32, 3, padding="same", activation="relu"))
cnn_model.add(MaxPool2D())

cnn_model.add(Conv2D(32, 3, padding="same", activation="relu"))
cnn_model.add(MaxPool2D())

cnn_model.add(Conv2D(64, 3, padding="same", activation="relu"))
cnn_model.add(MaxPool2D())
cnn_model.add(Dropout(0.4))  # To prevent overfitting

cnn_model.add(Flatten())
cnn_model.add(Dense(128,activation="relu"))
cnn_model.add(Dense(64,activation="relu"))
cnn_model.add(Dense(1, activation="sigmoid"))  # When 3 classes together will be used, use - 
                                               # cnn_model.add(Dense(3, activation="softmax"))

cnn_model.compile(optimizer = model_optimizer, loss = model_loss, metrics = model_accuracy)
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 224, 224, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 32)        9248
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 128)               401536
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 456,993
# Trainable params: 456,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Plot
plot_model(cnn_model,show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

# %%
# Model fit
history = cnn_model.fit(train_iter, validation_data=valid_iter, steps_per_epoch=len(model_train_x)/32, epochs=model_epochs, callbacks=model_callbacks)
# Out:
# Epoch 1/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5969 - acc: 0.7204 - mse: 0.2030INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 402ms/step - loss: 0.5969 - acc: 0.7204 - mse: 0.2030 - val_loss: 0.5791 - val_acc: 0.7217 - val_mse: 0.1963 - lr: 0.0010
# Epoch 2/100
# 143/143 [==============================] - 57s 396ms/step - loss: 0.5885 - acc: 0.7217 - mse: 0.1997 - val_loss: 0.5804 - val_acc: 0.7217 - val_mse: 0.1967 - lr: 0.0010
# Epoch 3/100
# 143/143 [==============================] - 57s 395ms/step - loss: 0.5823 - acc: 0.7217 - mse: 0.1972 - val_loss: 0.5803 - val_acc: 0.7217 - val_mse: 0.1968 - lr: 0.0010
# Epoch 4/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5791 - acc: 0.7217 - mse: 0.1960
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 143/143 [==============================] - 57s 395ms/step - loss: 0.5791 - acc: 0.7217 - mse: 0.1960 - val_loss: 0.5818 - val_acc: 0.7217 - val_mse: 0.1972 - lr: 0.0010
# Epoch 5/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5726 - acc: 0.7217 - mse: 0.1939INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 405ms/step - loss: 0.5726 - acc: 0.7217 - mse: 0.1939 - val_loss: 0.5770 - val_acc: 0.7217 - val_mse: 0.1955 - lr: 1.0000e-04
# Epoch 6/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5721 - acc: 0.7217 - mse: 0.1936INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 407ms/step - loss: 0.5721 - acc: 0.7217 - mse: 0.1936 - val_loss: 0.5749 - val_acc: 0.7217 - val_mse: 0.1949 - lr: 1.0000e-04
# Epoch 7/100
# 143/143 [==============================] - 57s 396ms/step - loss: 0.5711 - acc: 0.7217 - mse: 0.1931 - val_loss: 0.5756 - val_acc: 0.7217 - val_mse: 0.1951 - lr: 1.0000e-04
# Epoch 8/100
# 143/143 [==============================] - 57s 395ms/step - loss: 0.5722 - acc: 0.7217 - mse: 0.1936 - val_loss: 0.5759 - val_acc: 0.7217 - val_mse: 0.1952 - lr: 1.0000e-04
# Epoch 9/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5700 - acc: 0.7217 - mse: 0.1929
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001.
# 143/143 [==============================] - 57s 394ms/step - loss: 0.5700 - acc: 0.7217 - mse: 0.1929 - val_loss: 0.5811 - val_acc: 0.7217 - val_mse: 0.1968 - lr: 1.0000e-04
# Epoch 10/100
# 143/143 [==============================] - 57s 397ms/step - loss: 0.5721 - acc: 0.7217 - mse: 0.1934 - val_loss: 0.5764 - val_acc: 0.7217 - val_mse: 0.1954 - lr: 1.0000e-04
# Epoch 11/100
# 143/143 [==============================] - 57s 398ms/step - loss: 0.5712 - acc: 0.7217 - mse: 0.1931 - val_loss: 0.5756 - val_acc: 0.7217 - val_mse: 0.1951 - lr: 1.0000e-04
# Epoch 12/100
# 143/143 [==============================] - 57s 396ms/step - loss: 0.5696 - acc: 0.7217 - mse: 0.1926 - val_loss: 0.5757 - val_acc: 0.7217 - val_mse: 0.1951 - lr: 1.0000e-04
# Epoch 13/100
# 143/143 [==============================] - 57s 393ms/step - loss: 0.5693 - acc: 0.7217 - mse: 0.1925 - val_loss: 0.5755 - val_acc: 0.7217 - val_mse: 0.1950 - lr: 1.0000e-04
# Epoch 14/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5721 - acc: 0.7217 - mse: 0.1933INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 406ms/step - loss: 0.5721 - acc: 0.7217 - mse: 0.1933 - val_loss: 0.5743 - val_acc: 0.7217 - val_mse: 0.1946 - lr: 1.0000e-04
# Epoch 15/100
# 143/143 [==============================] - 56s 392ms/step - loss: 0.5709 - acc: 0.7217 - mse: 0.1928 - val_loss: 0.5751 - val_acc: 0.7217 - val_mse: 0.1949 - lr: 1.0000e-04
# Epoch 16/100
# 143/143 [==============================] - 56s 390ms/step - loss: 0.5691 - acc: 0.7217 - mse: 0.1924 - val_loss: 0.5746 - val_acc: 0.7217 - val_mse: 0.1946 - lr: 1.0000e-04
# Epoch 17/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5693 - acc: 0.7217 - mse: 0.1924INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 57s 400ms/step - loss: 0.5693 - acc: 0.7217 - mse: 0.1924 - val_loss: 0.5739 - val_acc: 0.7217 - val_mse: 0.1943 - lr: 1.0000e-04
# Epoch 18/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5692 - acc: 0.7217 - mse: 0.1922INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 402ms/step - loss: 0.5692 - acc: 0.7217 - mse: 0.1922 - val_loss: 0.5725 - val_acc: 0.7217 - val_mse: 0.1938 - lr: 1.0000e-04
# Epoch 19/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5685 - acc: 0.7217 - mse: 0.1922INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 407ms/step - loss: 0.5685 - acc: 0.7217 - mse: 0.1922 - val_loss: 0.5708 - val_acc: 0.7217 - val_mse: 0.1934 - lr: 1.0000e-04
# Epoch 20/100
# 143/143 [==============================] - 57s 397ms/step - loss: 0.5680 - acc: 0.7217 - mse: 0.1918 - val_loss: 0.5715 - val_acc: 0.7217 - val_mse: 0.1936 - lr: 1.0000e-04
# Epoch 21/100
# 143/143 [==============================] - 57s 395ms/step - loss: 0.5673 - acc: 0.7217 - mse: 0.1913 - val_loss: 0.5711 - val_acc: 0.7217 - val_mse: 0.1933 - lr: 1.0000e-04
# Epoch 22/100
# 143/143 [==============================] - 56s 392ms/step - loss: 0.5658 - acc: 0.7217 - mse: 0.1909 - val_loss: 0.5718 - val_acc: 0.7217 - val_mse: 0.1934 - lr: 1.0000e-04
# Epoch 23/100
# 143/143 [==============================] - 56s 387ms/step - loss: 0.5659 - acc: 0.7217 - mse: 0.1908 - val_loss: 0.5715 - val_acc: 0.7217 - val_mse: 0.1931 - lr: 1.0000e-04
# Epoch 24/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5621 - acc: 0.7217 - mse: 0.1892INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 400ms/step - loss: 0.5621 - acc: 0.7217 - mse: 0.1892 - val_loss: 0.5702 - val_acc: 0.7217 - val_mse: 0.1926 - lr: 1.0000e-04
# Epoch 25/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5632 - acc: 0.7217 - mse: 0.1897INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 403ms/step - loss: 0.5632 - acc: 0.7217 - mse: 0.1897 - val_loss: 0.5674 - val_acc: 0.7217 - val_mse: 0.1916 - lr: 1.0000e-04
# Epoch 26/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5632 - acc: 0.7215 - mse: 0.1897INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 403ms/step - loss: 0.5632 - acc: 0.7215 - mse: 0.1897 - val_loss: 0.5666 - val_acc: 0.7217 - val_mse: 0.1914 - lr: 1.0000e-04
# Epoch 27/100
# 143/143 [==============================] - 56s 388ms/step - loss: 0.5628 - acc: 0.7219 - mse: 0.1896 - val_loss: 0.5687 - val_acc: 0.7217 - val_mse: 0.1918 - lr: 1.0000e-04
# Epoch 28/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5630 - acc: 0.7225 - mse: 0.1893INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 408ms/step - loss: 0.5630 - acc: 0.7225 - mse: 0.1893 - val_loss: 0.5657 - val_acc: 0.7217 - val_mse: 0.1909 - lr: 1.0000e-04
# Epoch 29/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5604 - acc: 0.7236 - mse: 0.1886INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 409ms/step - loss: 0.5604 - acc: 0.7236 - mse: 0.1886 - val_loss: 0.5644 - val_acc: 0.7217 - val_mse: 0.1900 - lr: 1.0000e-04
# Epoch 30/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5596 - acc: 0.7256 - mse: 0.1882INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 409ms/step - loss: 0.5596 - acc: 0.7256 - mse: 0.1882 - val_loss: 0.5631 - val_acc: 0.7217 - val_mse: 0.1896 - lr: 1.0000e-04
# Epoch 31/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5583 - acc: 0.7265 - mse: 0.1879INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 412ms/step - loss: 0.5583 - acc: 0.7265 - mse: 0.1879 - val_loss: 0.5606 - val_acc: 0.7241 - val_mse: 0.1886 - lr: 1.0000e-04
# Epoch 32/100
# 143/143 [==============================] - 57s 396ms/step - loss: 0.5605 - acc: 0.7286 - mse: 0.1881 - val_loss: 0.5623 - val_acc: 0.7229 - val_mse: 0.1892 - lr: 1.0000e-04
# Epoch 33/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5580 - acc: 0.7304 - mse: 0.1872INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 404ms/step - loss: 0.5580 - acc: 0.7304 - mse: 0.1872 - val_loss: 0.5605 - val_acc: 0.7254 - val_mse: 0.1884 - lr: 1.0000e-04
# Epoch 34/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5548 - acc: 0.7315 - mse: 0.1862INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 403ms/step - loss: 0.5548 - acc: 0.7315 - mse: 0.1862 - val_loss: 0.5588 - val_acc: 0.7315 - val_mse: 0.1875 - lr: 1.0000e-04
# Epoch 35/100
# 143/143 [==============================] - 56s 391ms/step - loss: 0.5542 - acc: 0.7345 - mse: 0.1857 - val_loss: 0.5602 - val_acc: 0.7254 - val_mse: 0.1878 - lr: 1.0000e-04
# Epoch 36/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5536 - acc: 0.7362 - mse: 0.1853INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 407ms/step - loss: 0.5536 - acc: 0.7362 - mse: 0.1853 - val_loss: 0.5575 - val_acc: 0.7389 - val_mse: 0.1870 - lr: 1.0000e-04
# Epoch 37/100
# 143/143 [==============================] - 57s 394ms/step - loss: 0.5511 - acc: 0.7402 - mse: 0.1846 - val_loss: 0.5594 - val_acc: 0.7365 - val_mse: 0.1876 - lr: 1.0000e-04
# Epoch 38/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5524 - acc: 0.7434 - mse: 0.1848INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 57s 397ms/step - loss: 0.5524 - acc: 0.7434 - mse: 0.1848 - val_loss: 0.5571 - val_acc: 0.7352 - val_mse: 0.1864 - lr: 1.0000e-04
# Epoch 39/100
# 143/143 [==============================] - 55s 382ms/step - loss: 0.5503 - acc: 0.7445 - mse: 0.1841 - val_loss: 0.5609 - val_acc: 0.7340 - val_mse: 0.1884 - lr: 1.0000e-04
# Epoch 40/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5522 - acc: 0.7406 - mse: 0.1849INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 56s 392ms/step - loss: 0.5522 - acc: 0.7406 - mse: 0.1849 - val_loss: 0.5552 - val_acc: 0.7365 - val_mse: 0.1859 - lr: 1.0000e-04
# Epoch 41/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5491 - acc: 0.7430 - mse: 0.1834INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 57s 395ms/step - loss: 0.5491 - acc: 0.7430 - mse: 0.1834 - val_loss: 0.5538 - val_acc: 0.7340 - val_mse: 0.1848 - lr: 1.0000e-04
# Epoch 42/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5459 - acc: 0.7443 - mse: 0.1822INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 57s 394ms/step - loss: 0.5459 - acc: 0.7443 - mse: 0.1822 - val_loss: 0.5517 - val_acc: 0.7426 - val_mse: 0.1840 - lr: 1.0000e-04
# Epoch 43/100
# 143/143 [==============================] - 55s 381ms/step - loss: 0.5479 - acc: 0.7480 - mse: 0.1827 - val_loss: 0.5537 - val_acc: 0.7438 - val_mse: 0.1850 - lr: 1.0000e-04
# Epoch 44/100
# 143/143 [==============================] - 55s 381ms/step - loss: 0.5451 - acc: 0.7462 - mse: 0.1817 - val_loss: 0.5532 - val_acc: 0.7414 - val_mse: 0.1841 - lr: 1.0000e-04
# Epoch 45/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5465 - acc: 0.7495 - mse: 0.1823INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 56s 393ms/step - loss: 0.5465 - acc: 0.7495 - mse: 0.1823 - val_loss: 0.5487 - val_acc: 0.7414 - val_mse: 0.1829 - lr: 1.0000e-04
# Epoch 46/100
# 143/143 [==============================] - 55s 379ms/step - loss: 0.5449 - acc: 0.7473 - mse: 0.1817 - val_loss: 0.5522 - val_acc: 0.7438 - val_mse: 0.1840 - lr: 1.0000e-04
# Epoch 47/100
# 143/143 [==============================] - 55s 381ms/step - loss: 0.5428 - acc: 0.7510 - mse: 0.1805 - val_loss: 0.5563 - val_acc: 0.7414 - val_mse: 0.1859 - lr: 1.0000e-04
# Epoch 48/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5406 - acc: 0.7491 - mse: 0.1798INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 56s 393ms/step - loss: 0.5406 - acc: 0.7491 - mse: 0.1798 - val_loss: 0.5456 - val_acc: 0.7463 - val_mse: 0.1814 - lr: 1.0000e-04
# Epoch 49/100
# 143/143 [==============================] - 54s 378ms/step - loss: 0.5425 - acc: 0.7495 - mse: 0.1803 - val_loss: 0.5473 - val_acc: 0.7377 - val_mse: 0.1823 - lr: 1.0000e-04
# Epoch 50/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5417 - acc: 0.7482 - mse: 0.1803INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 56s 389ms/step - loss: 0.5417 - acc: 0.7482 - mse: 0.1803 - val_loss: 0.5445 - val_acc: 0.7451 - val_mse: 0.1810 - lr: 1.0000e-04
# Epoch 51/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5406 - acc: 0.7517 - mse: 0.1798INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 56s 389ms/step - loss: 0.5406 - acc: 0.7517 - mse: 0.1798 - val_loss: 0.5427 - val_acc: 0.7463 - val_mse: 0.1805 - lr: 1.0000e-04
# Epoch 52/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5354 - acc: 0.7530 - mse: 0.1777INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 401ms/step - loss: 0.5354 - acc: 0.7530 - mse: 0.1777 - val_loss: 0.5419 - val_acc: 0.7451 - val_mse: 0.1798 - lr: 1.0000e-04
# Epoch 53/100
# 143/143 [==============================] - 56s 391ms/step - loss: 0.5355 - acc: 0.7506 - mse: 0.1774 - val_loss: 0.5431 - val_acc: 0.7525 - val_mse: 0.1801 - lr: 1.0000e-04
# Epoch 54/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5354 - acc: 0.7510 - mse: 0.1776INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 404ms/step - loss: 0.5354 - acc: 0.7510 - mse: 0.1776 - val_loss: 0.5387 - val_acc: 0.7537 - val_mse: 0.1783 - lr: 1.0000e-04
# Epoch 55/100
# 143/143 [==============================] - 57s 393ms/step - loss: 0.5344 - acc: 0.7523 - mse: 0.1771 - val_loss: 0.5411 - val_acc: 0.7549 - val_mse: 0.1791 - lr: 1.0000e-04
# Epoch 56/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5363 - acc: 0.7526 - mse: 0.1777INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 403ms/step - loss: 0.5363 - acc: 0.7526 - mse: 0.1777 - val_loss: 0.5349 - val_acc: 0.7500 - val_mse: 0.1769 - lr: 1.0000e-04
# Epoch 57/100
# 143/143 [==============================] - 57s 394ms/step - loss: 0.5364 - acc: 0.7506 - mse: 0.1777 - val_loss: 0.5398 - val_acc: 0.7475 - val_mse: 0.1786 - lr: 1.0000e-04
# Epoch 58/100
# 143/143 [==============================] - 57s 393ms/step - loss: 0.5369 - acc: 0.7508 - mse: 0.1781 - val_loss: 0.5380 - val_acc: 0.7475 - val_mse: 0.1782 - lr: 1.0000e-04
# Epoch 59/100
# 143/143 [==============================] - 57s 396ms/step - loss: 0.5334 - acc: 0.7545 - mse: 0.1768 - val_loss: 0.5370 - val_acc: 0.7463 - val_mse: 0.1784 - lr: 1.0000e-04
# Epoch 60/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5312 - acc: 0.7545 - mse: 0.1758INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 406ms/step - loss: 0.5312 - acc: 0.7545 - mse: 0.1758 - val_loss: 0.5337 - val_acc: 0.7475 - val_mse: 0.1769 - lr: 1.0000e-04
# Epoch 61/100
# 143/143 [==============================] - 57s 394ms/step - loss: 0.5306 - acc: 0.7536 - mse: 0.1756 - val_loss: 0.5348 - val_acc: 0.7389 - val_mse: 0.1776 - lr: 1.0000e-04
# Epoch 62/100
# 143/143 [==============================] - 57s 393ms/step - loss: 0.5294 - acc: 0.7560 - mse: 0.1751 - val_loss: 0.5422 - val_acc: 0.7500 - val_mse: 0.1801 - lr: 1.0000e-04
# Epoch 63/100
# 143/143 [==============================] - 56s 390ms/step - loss: 0.5307 - acc: 0.7513 - mse: 0.1760 - val_loss: 0.5425 - val_acc: 0.7438 - val_mse: 0.1809 - lr: 1.0000e-04
# Epoch 64/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5252 - acc: 0.7545 - mse: 0.1738INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 60s 416ms/step - loss: 0.5252 - acc: 0.7545 - mse: 0.1738 - val_loss: 0.5336 - val_acc: 0.7525 - val_mse: 0.1768 - lr: 1.0000e-04
# Epoch 65/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5297 - acc: 0.7530 - mse: 0.1753INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 407ms/step - loss: 0.5297 - acc: 0.7530 - mse: 0.1753 - val_loss: 0.5309 - val_acc: 0.7549 - val_mse: 0.1757 - lr: 1.0000e-04
# Epoch 66/100
# 143/143 [==============================] - 56s 392ms/step - loss: 0.5244 - acc: 0.7565 - mse: 0.1736 - val_loss: 0.5343 - val_acc: 0.7463 - val_mse: 0.1776 - lr: 1.0000e-04
# Epoch 67/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5281 - acc: 0.7517 - mse: 0.1750INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 58s 404ms/step - loss: 0.5281 - acc: 0.7517 - mse: 0.1750 - val_loss: 0.5307 - val_acc: 0.7562 - val_mse: 0.1757 - lr: 1.0000e-04
# Epoch 68/100
# 143/143 [==============================] - 56s 393ms/step - loss: 0.5266 - acc: 0.7545 - mse: 0.1742 - val_loss: 0.5310 - val_acc: 0.7586 - val_mse: 0.1756 - lr: 1.0000e-04
# Epoch 69/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5245 - acc: 0.7569 - mse: 0.1735INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 410ms/step - loss: 0.5245 - acc: 0.7569 - mse: 0.1735 - val_loss: 0.5300 - val_acc: 0.7562 - val_mse: 0.1754 - lr: 1.0000e-04
# Epoch 70/100
# 143/143 [==============================] - 57s 394ms/step - loss: 0.5280 - acc: 0.7545 - mse: 0.1752 - val_loss: 0.5304 - val_acc: 0.7537 - val_mse: 0.1759 - lr: 1.0000e-04
# Epoch 71/100
# 143/143 [==============================] - 56s 391ms/step - loss: 0.5260 - acc: 0.7576 - mse: 0.1739 - val_loss: 0.5347 - val_acc: 0.7463 - val_mse: 0.1775 - lr: 1.0000e-04
# Epoch 72/100
# 143/143 [==============================] - 57s 393ms/step - loss: 0.5283 - acc: 0.7569 - mse: 0.1745 - val_loss: 0.5322 - val_acc: 0.7574 - val_mse: 0.1763 - lr: 1.0000e-04
# Epoch 73/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5248 - acc: 0.7532 - mse: 0.1739INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/CNN_Medical_Imaging/Model_check_points/v1/assets
# 143/143 [==============================] - 59s 410ms/step - loss: 0.5248 - acc: 0.7532 - mse: 0.1739 - val_loss: 0.5284 - val_acc: 0.7549 - val_mse: 0.1748 - lr: 1.0000e-04
# Epoch 74/100
# 143/143 [==============================] - 58s 400ms/step - loss: 0.5241 - acc: 0.7558 - mse: 0.1735 - val_loss: 0.5297 - val_acc: 0.7537 - val_mse: 0.1756 - lr: 1.0000e-04
# Epoch 75/100
# 143/143 [==============================] - 56s 390ms/step - loss: 0.5243 - acc: 0.7549 - mse: 0.1735 - val_loss: 0.5347 - val_acc: 0.7500 - val_mse: 0.1778 - lr: 1.0000e-04
# Epoch 76/100
# 143/143 [==============================] - 57s 396ms/step - loss: 0.5217 - acc: 0.7580 - mse: 0.1721 - val_loss: 0.5312 - val_acc: 0.7438 - val_mse: 0.1765 - lr: 1.0000e-04
# Epoch 77/100
# 143/143 [==============================] - 57s 395ms/step - loss: 0.5196 - acc: 0.7608 - mse: 0.1715 - val_loss: 0.5337 - val_acc: 0.7488 - val_mse: 0.1771 - lr: 1.0000e-04
# Epoch 78/100
# 143/143 [==============================] - 56s 390ms/step - loss: 0.5252 - acc: 0.7591 - mse: 0.1734 - val_loss: 0.5417 - val_acc: 0.7426 - val_mse: 0.1811 - lr: 1.0000e-04
# Epoch 79/100
# 143/143 [==============================] - 58s 403ms/step - loss: 0.5222 - acc: 0.7593 - mse: 0.1727 - val_loss: 0.5347 - val_acc: 0.7562 - val_mse: 0.1776 - lr: 1.0000e-04
# Epoch 80/100
# 143/143 [==============================] - 57s 397ms/step - loss: 0.5230 - acc: 0.7560 - mse: 0.1732 - val_loss: 0.5339 - val_acc: 0.7537 - val_mse: 0.1775 - lr: 1.0000e-04
# Epoch 81/100
# 143/143 [==============================] - 56s 391ms/step - loss: 0.5193 - acc: 0.7599 - mse: 0.1714 - val_loss: 0.5314 - val_acc: 0.7500 - val_mse: 0.1769 - lr: 1.0000e-04
# Epoch 82/100
# 143/143 [==============================] - 56s 390ms/step - loss: 0.5176 - acc: 0.7613 - mse: 0.1711 - val_loss: 0.5304 - val_acc: 0.7463 - val_mse: 0.1763 - lr: 1.0000e-04
# Epoch 83/100
# 144/143 [==============================] - ETA: 0s - loss: 0.5195 - acc: 0.7586 - mse: 0.1718Restoring model weights from the end of the best epoch: 73.
# 143/143 [==============================] - 56s 391ms/step - loss: 0.5195 - acc: 0.7586 - mse: 0.1718 - val_loss: 0.5362 - val_acc: 0.7525 - val_mse: 0.1787 - lr: 1.0000e-04
# Epoch 83: early stopping

# %%
# Save model
keras.models.save_model(cnn_model, "cnn_model_v1.h5", save_format="h5")

# %%
# Model History Plot
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
mse = history.history['mse']
val_mse = history.history['val_mse']
epochs_range = range(len(history.history['loss']))

plt.figure(0)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, acc, 'r', label='Training Accuracy')
plt.plot(epochs_range, val_acc, 'g', label='Validation Accuracy')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='lower right')
plt.title('Training vs Validation Accuracy')

plt.figure(1)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.title('Training vs Validation Loss')

plt.figure(2)
plt.figure(figsize=(6, 6))
plt.plot(epochs_range, mse, label='Training mse')
plt.plot(epochs_range, val_mse, label='Validation mse')
plt.xlabel("Num of Epochs")
plt.ylabel("MSE")
plt.legend(loc='upper right')
plt.title('Training vs Validation MSE')

plt.show()

# %% [markdown]
# ## Prediction Stats

# %%
# Finding Prediction Error

# Since for now we are dealing with a binary classifciation problem (healthy bones and fractured bones), we use the following method
# Later when we continue working with all 3 classes (healthy bones, fractured bones and bones beyond repair), we will change the below maths accordingly
model_test_prediction_labels = cnn_model.predict(model_test_x)
model_test_prediction_list = []
for label_prediction in model_test_prediction_labels:
  if label_prediction[0] > 0.5:
    model_test_prediction_list.append(1)
  else:
    model_test_prediction_list.append(0)

prediction_error = np.sum(np.not_equal(model_test_prediction_list, list(model_test_y))) / model_test_y.shape[0]
print(f"The prediction error for the model is {prediction_error}")
# Out:
# The prediction error for the model is 0.24750830564784054

# %% [markdown]
# #### The model prediction error should be close to zero. The above value will show how much the model needs more tuning and optimization in order to have prediction error closer to zero.

# %% [markdown]
# ## Metric Stats

# %%
# Classification Report:
print('Classification Report: ')
print(classification_report(list(model_test_y), model_test_prediction_list, target_names=["0","1"]))

# Confusion Matrix
print('Confusion Matrix: ')
cm = confusion_matrix(model_test_prediction_list, list(model_test_y))
plt.figure(figsize = (7.5,5))
sns.set(font_scale=1.4) # for label size
sns.heatmap(cm, annot=True, annot_kws={"size": 20},cmap="YlGnBu") # font size
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.97      0.85       435
#            1       0.70      0.19      0.29       167
#
#     accuracy                           0.75       602
#    macro avg       0.73      0.58      0.57       602
# weighted avg       0.74      0.75      0.70       602
#
# Confusion Matrix:
